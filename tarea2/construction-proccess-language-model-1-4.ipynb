# %% [markdown]
# (5p) Read the files and build two large consolidate files that are the union of all the documents in 20N and BAC.

# %% [markdown]
# **SECCION PARA COLOCAR DONDE TIENES UBICADOS LOS DATASETS DE 20NEWS.ZIP Y BAC.ZIP**

# %%
# "CAMBIAR POR TU UBICACION EN TU PC"
newsgroups_dataset = "20news-18828.tar.gz" # http://qwone.com/~jason/20Newsgroups/20news-18828.tar.gz
bac_dataset = "BAC.zip" # https://huggingface.co/datasets/barilan/blog_authorship_corpus

# !mkdir -p datasets
# !tar -xzf {newsgroups_dataset} -C datasets
# !unzip -o {bac_dataset} -d datasets
# !unzip -o "datasets/blogs.zip" -d datasets
# !mkdir -p large-files
# Out:
# Archive:  BAC.zip
# warning:  stripped absolute path spec from /
# mapname:  conversion of  failed
#  extracting: datasets/blogs.zip
#  extracting: datasets/5114.male.25.indUnk.Scorpio.xml
# Archive:  datasets/blogs.zip
#   inflating: datasets/blogs/1000331.female.37.indUnk.Leo.xml
#   inflating: datasets/blogs/1000866.female.17.Student.Libra.xml
#   inflating: datasets/blogs/1004904.male.23.Arts.Capricorn.xml
#   inflating: datasets/blogs/1005076.female.25.Arts.Cancer.xml
#   inflating: datasets/blogs/1005545.male.25.Engineering.Sagittarius.xml
#   inflating: datasets/blogs/1007188.male.48.Religion.Libra.xml
#   inflating: datasets/blogs/100812.female.26.Architecture.Aries.xml
#   inflating: datasets/blogs/1008329.female.16.Student.Pisces.xml
#   inflating: datasets/blogs/1009572.male.25.indUnk.Cancer.xml
#   inflating: datasets/blogs/1011153.female.27.Technology.Virgo.xml
#   inflating: datasets/blogs/1011289.female.25.indUnk.Libra.xml
#   inflating: datasets/blogs/1011311.female.17.indUnk.Scorpio.xml
#   inflating: datasets/blogs/1013637.male.17.RealEstate.Virgo.xml
#   inflating: datasets/blogs/1015252.female.23.indUnk.Pisces.xml
#   inflating: datasets/blogs/1015556.male.34.Technology.Virgo.xml
#   inflating: datasets/blogs/1016560.male.41.Publishing.Sagittarius.xml
#   inflating: datasets/blogs/1016738.male.26.Publishing.Libra.xml
#   inflating: datasets/blogs/1016787.female.24.Communications-Media.Leo.xml
#   inflating: datasets/blogs/1019224.female.27.RealEstate.Libra.xml
#   inflating: datasets/blogs/1019622.female.24.indUnk.Aquarius.xml
#   inflating: datasets/blogs/1019710.male.16.Student.Pisces.xml
#   inflating: datasets/blogs/1021779.female.25.indUnk.Scorpio.xml
#   inflating: datasets/blogs/1022037.male.23.indUnk.Cancer.xml
#   inflating: datasets/blogs/1022086.female.17.Student.Cancer.xml
#   inflating: datasets/blogs/1024234.female.17.indUnk.Libra.xml
#   inflating: datasets/blogs/1025783.female.17.Student.Gemini.xml
#   inflating: datasets/blogs/1026164.female.23.Education.Aries.xml
#   inflating: datasets/blogs/1026443.female.15.Student.Scorpio.xml
#   inflating: datasets/blogs/1028027.female.16.indUnk.Libra.xml
#   inflating: datasets/blogs/1028257.male.26.Education.Aries.xml
#   inflating: datasets/blogs/1029959.male.17.indUnk.Aries.xml
#   inflating: datasets/blogs/1031806.male.17.Technology.Sagittarius.xml
#   inflating: datasets/blogs/1032153.male.27.Technology.Pisces.xml
#   inflating: datasets/blogs/1032591.female.24.Banking.Aquarius.xml
#   inflating: datasets/blogs/1032824.female.15.Student.Libra.xml
#   inflating: datasets/blogs/1034874.female.43.Publishing.Capricorn.xml
#   inflating: datasets/blogs/1039136.male.24.Student.Capricorn.xml
#   inflating: datasets/blogs/1039908.female.16.indUnk.Gemini.xml
#   inflating: datasets/blogs/1040084.male.17.indUnk.Taurus.xml
#   inflating: datasets/blogs/1042993.male.15.Student.Sagittarius.xml
#   inflating: datasets/blogs/1043329.male.23.Government.Pisces.xml
#   inflating: datasets/blogs/1043569.male.26.indUnk.Virgo.xml
#   inflating: datasets/blogs/1043785.female.26.Biotech.Leo.xml
#   inflating: datasets/blogs/1044338.female.23.Student.Leo.xml
#   inflating: datasets/blogs/1045289.female.25.Arts.Aquarius.xml
#   inflating: datasets/blogs/1045316.male.27.Non-Profit.Capricorn.xml
#   inflating: datasets/blogs/1045831.male.23.Student.Libra.xml
#   inflating: datasets/blogs/1046946.female.25.Arts.Virgo.xml
#   inflating: datasets/blogs/1047241.male.16.indUnk.Aries.xml
#   inflating: datasets/blogs/1050060.female.24.Student.Pisces.xml
#   inflating: datasets/blogs/1051122.female.17.Student.Libra.xml
#   inflating: datasets/blogs/1052611.male.23.Student.Aries.xml
#   inflating: datasets/blogs/1054833.female.24.indUnk.Scorpio.xml
#   inflating: datasets/blogs/1055228.female.16.Student.Cancer.xml
#   inflating: datasets/blogs/1056232.female.17.indUnk.Aquarius.xml
#   inflating: datasets/blogs/1056581.female.26.indUnk.Leo.xml
#   inflating: datasets/blogs/105748.female.26.Student.Scorpio.xml
#   inflating: datasets/blogs/1057539.female.33.Telecommunications.Pisces.xml
#   inflating: datasets/blogs/1057945.female.26.indUnk.Leo.xml
#   inflating: datasets/blogs/1058543.female.24.indUnk.Sagittarius.xml
#   inflating: datasets/blogs/1060087.male.27.Arts.Leo.xml
#   inflating: datasets/blogs/1060727.female.23.indUnk.Aries.xml
#   inflating: datasets/blogs/106160.female.27.Student.Sagittarius.xml
#   inflating: datasets/blogs/1062652.female.25.indUnk.Aries.xml
#   inflating: datasets/blogs/1063313.female.16.Student.Libra.xml
#   inflating: datasets/blogs/1065973.female.23.indUnk.Virgo.xml
#   inflating: datasets/blogs/1066127.male.23.Technology.Taurus.xml
#   inflating: datasets/blogs/106651.male.25.indUnk.Leo.xml
#   inflating: datasets/blogs/1067319.male.26.Non-Profit.Aries.xml
#   inflating: datasets/blogs/106738.male.25.Internet.Leo.xml
#   inflating: datasets/blogs/1068622.male.24.Government.Aquarius.xml
#   inflating: datasets/blogs/1068893.male.25.indUnk.Leo.xml
#   inflating: datasets/blogs/1070326.male.24.Government.Aquarius.xml
#   inflating: datasets/blogs/1070540.female.36.Technology.Scorpio.xml
#   inflating: datasets/blogs/1073035.female.45.Education.Cancer.xml
#   inflating: datasets/blogs/1074721.male.23.Student.Aquarius.xml
#   inflating: datasets/blogs/1075230.male.17.Student.Cancer.xml
#   inflating: datasets/blogs/1076134.female.25.Arts.Gemini.xml
#   inflating: datasets/blogs/1076363.male.40.Communications-Media.Pisces.xml
#   inflating: datasets/blogs/1077758.male.24.Student.Scorpio.xml
#   inflating: datasets/blogs/1077954.male.26.indUnk.Gemini.xml
#   inflating: datasets/blogs/1078077.female.38.Arts.Aries.xml
#   inflating: datasets/blogs/1078410.male.16.indUnk.Cancer.xml
#   inflating: datasets/blogs/1079521.female.24.indUnk.Capricorn.xml
#   inflating: datasets/blogs/108212.female.27.Student.Taurus.xml
#   inflating: datasets/blogs/1083777.male.27.Technology.Libra.xml
#   inflating: datasets/blogs/1084212.female.35.indUnk.Capricorn.xml
#   inflating: datasets/blogs/1084668.female.15.Student.Capricorn.xml
#   inflating: datasets/blogs/1084944.female.26.Arts.Leo.xml
#   inflating: datasets/blogs/1086142.female.24.Arts.Leo.xml
#   inflating: datasets/blogs/1086405.male.25.Manufacturing.Taurus.xml
#   inflating: datasets/blogs/1087356.female.23.indUnk.Virgo.xml
#   inflating: datasets/blogs/108780.female.25.indUnk.Leo.xml
#   inflating: datasets/blogs/1088145.male.26.indUnk.Capricorn.xml
#   inflating: datasets/blogs/1088782.male.27.Engineering.Aquarius.xml
#   inflating: datasets/blogs/1089137.female.17.indUnk.Taurus.xml
#   inflating: datasets/blogs/1089661.female.26.indUnk.Libra.xml
#   inflating: datasets/blogs/1089670.female.17.Student.Sagittarius.xml
#   inflating: datasets/blogs/1090235.female.17.indUnk.Aquarius.xml
#   inflating: datasets/blogs/1090547.male.14.Religion.Capricorn.xml
#   inflating: datasets/blogs/1091067.male.24.Technology.Cancer.xml
#   inflating: datasets/blogs/1091544.male.36.indUnk.Pisces.xml
#   inflating: datasets/blogs/1091574.female.15.Student.Taurus.xml
#   inflating: datasets/blogs/1091912.female.14.Student.Leo.xml
#   inflating: datasets/blogs/1092135.female.17.indUnk.Leo.xml
#   inflating: datasets/blogs/1092346.female.16.indUnk.Gemini.xml
#   inflating: datasets/blogs/1093457.male.16.Technology.Virgo.xml
#   inflating: datasets/blogs/1093691.male.17.Technology.Taurus.xml
#   inflating: datasets/blogs/1094221.female.23.Education.Leo.xml
#   inflating: datasets/blogs/109656.male.36.LawEnforcement-Security.Pisces.xml
#   inflating: datasets/blogs/1097617.female.25.Communications-Media.Sagittarius.xml
#   inflating: datasets/blogs/1097941.female.25.Marketing.Pisces.xml
#   inflating: datasets/blogs/1098293.male.25.Engineering.Leo.xml
#   inflating: datasets/blogs/1098541.male.15.indUnk.Capricorn.xml
#   inflating: datasets/blogs/1100515.female.17.Student.Aries.xml
#   inflating: datasets/blogs/1101683.female.16.Arts.Libra.xml
#   inflating: datasets/blogs/1102011.male.15.Student.Sagittarius.xml
#   inflating: datasets/blogs/1103016.male.16.Student.Gemini.xml
#   inflating: datasets/blogs/1103084.male.34.Education.Pisces.xml
#   inflating: datasets/blogs/1103171.female.25.indUnk.Aries.xml
#   inflating: datasets/blogs/1103575.female.17.indUnk.Scorpio.xml
#   inflating: datasets/blogs/1104980.male.23.Sports-Recreation.Sagittarius.xml
#   inflating: datasets/blogs/1105342.female.33.Internet.Gemini.xml
#   inflating: datasets/blogs/1107146.female.16.Student.Libra.xml
#   inflating: datasets/blogs/1107975.male.17.Student.Pisces.xml
#   inflating: datasets/blogs/1108003.male.36.Internet.Pisces.xml
#   inflating: datasets/blogs/110854.male.25.indUnk.Virgo.xml
#   inflating: datasets/blogs/1110091.male.36.Technology.Virgo.xml
#   inflating: datasets/blogs/1110189.male.23.indUnk.Aries.xml
#   inflating: datasets/blogs/1110391.male.27.Law.Cancer.xml
#   inflating: datasets/blogs/1110574.female.23.Arts.Aquarius.xml
#   inflating: datasets/blogs/1111991.female.33.indUnk.Taurus.xml
#   inflating: datasets/blogs/1112526.female.24.indUnk.Sagittarius.xml
#   inflating: datasets/blogs/1112708.female.17.indUnk.Cancer.xml
#   inflating: datasets/blogs/1112886.female.15.Student.Capricorn.xml
#   inflating: datasets/blogs/1113052.female.25.indUnk.Cancer.xml
#   inflating: datasets/blogs/1113541.male.26.indUnk.Aries.xml
#   inflating: datasets/blogs/1113692.female.25.Non-Profit.Gemini.xml
#   inflating: datasets/blogs/1114816.male.47.Technology.Pisces.xml
#   inflating: datasets/blogs/1115374.male.17.indUnk.Scorpio.xml
#   inflating: datasets/blogs/1117055.female.17.Student.Aquarius.xml
#   inflating: datasets/blogs/1117656.male.17.indUnk.Pisces.xml
#   inflating: datasets/blogs/1119280.female.27.indUnk.Gemini.xml
#   inflating: datasets/blogs/1119650.female.23.Student.Cancer.xml
#   inflating: datasets/blogs/1119851.male.17.indUnk.Virgo.xml
#   inflating: datasets/blogs/112265.female.23.indUnk.Taurus.xml
#   inflating: datasets/blogs/11253.male.26.Technology.Aquarius.xml
#   inflating: datasets/blogs/1125373.male.17.Student.Taurus.xml
#   inflating: datasets/blogs/1125433.male.48.Military.Aquarius.xml
#   inflating: datasets/blogs/1125459.female.16.indUnk.Libra.xml
#   inflating: datasets/blogs/1125546.male.27.Law.Aries.xml
#   inflating: datasets/blogs/1127124.male.25.indUnk.Gemini.xml
#   inflating: datasets/blogs/1130595.male.16.indUnk.Sagittarius.xml
#   inflating: datasets/blogs/1131329.male.13.indUnk.Leo.xml
#   inflating: datasets/blogs/1131517.female.17.indUnk.Gemini.xml
#   inflating: datasets/blogs/1131982.male.24.Government.Libra.xml
#   inflating: datasets/blogs/1132409.female.41.indUnk.Taurus.xml
#   inflating: datasets/blogs/113390.male.24.Museums-Libraries.Gemini.xml
#   inflating: datasets/blogs/1134486.male.45.indUnk.Aquarius.xml
#   inflating: datasets/blogs/1135325.male.27.Science.Libra.xml
#   inflating: datasets/blogs/1135724.male.34.Internet.Cancer.xml
#   inflating: datasets/blogs/1135804.male.33.indUnk.Libra.xml
#   inflating: datasets/blogs/1136785.male.17.Student.Pisces.xml
#   inflating: datasets/blogs/1137273.male.16.Student.Aquarius.xml
#   inflating: datasets/blogs/1137547.female.15.Arts.Scorpio.xml
#   inflating: datasets/blogs/1138306.female.17.indUnk.Gemini.xml
#   inflating: datasets/blogs/1142598.male.24.indUnk.Aquarius.xml
#   inflating: datasets/blogs/1143104.male.23.Student.Gemini.xml
#   inflating: datasets/blogs/1143324.male.26.Internet.Virgo.xml
#   inflating: datasets/blogs/1144172.male.17.indUnk.Libra.xml
#   inflating: datasets/blogs/1145753.male.25.indUnk.Virgo.xml
#   inflating: datasets/blogs/114645.male.17.Student.Virgo.xml
#   inflating: datasets/blogs/1146482.female.33.indUnk.Virgo.xml
#   inflating: datasets/blogs/1149009.male.25.Technology.Gemini.xml
#   inflating: datasets/blogs/1149422.female.34.Publishing.Scorpio.xml
#   inflating: datasets/blogs/1149997.female.27.indUnk.Leo.xml
#   inflating: datasets/blogs/1151815.male.25.Education.Leo.xml
#   inflating: datasets/blogs/1152012.female.16.indUnk.Leo.xml
#   inflating: datasets/blogs/1153868.male.14.indUnk.Gemini.xml
#   inflating: datasets/blogs/1155029.female.17.Student.Leo.xml
#   inflating: datasets/blogs/1155573.male.23.indUnk.Leo.xml
#   inflating: datasets/blogs/1156278.male.37.Internet.Taurus.xml
#   inflating: datasets/blogs/1157144.female.17.Student.Libra.xml
#   inflating: datasets/blogs/1157178.female.26.indUnk.Gemini.xml
#   inflating: datasets/blogs/1157338.male.25.Technology.Virgo.xml
#   inflating: datasets/blogs/1157658.male.25.indUnk.Leo.xml
#   inflating: datasets/blogs/1158355.male.15.Student.Leo.xml
#   inflating: datasets/blogs/1158868.female.24.Student.Leo.xml
#   inflating: datasets/blogs/1159057.male.25.Advertising.Scorpio.xml
#   inflating: datasets/blogs/1160168.male.25.Science.Aries.xml
#   inflating: datasets/blogs/1162051.female.23.LawEnforcement-Security.Scorpio.xml
#   inflating: datasets/blogs/1162265.male.17.Student.Aries.xml
#   inflating: datasets/blogs/1163257.female.24.indUnk.Gemini.xml
#   inflating: datasets/blogs/1163948.female.24.indUnk.Capricorn.xml
#   inflating: datasets/blogs/1164965.male.16.Student.Virgo.xml
#   inflating: datasets/blogs/1166708.female.26.Arts.Aquarius.xml
#   inflating: datasets/blogs/1169141.male.33.Arts.Capricorn.xml
#   inflating: datasets/blogs/1169202.male.26.Science.Libra.xml
#   inflating: datasets/blogs/1169580.female.44.Technology.Taurus.xml
#   inflating: datasets/blogs/1170834.female.27.Communications-Media.Sagittarius.xml
#   inflating: datasets/blogs/1171545.female.17.Non-Profit.Cancer.xml
#   inflating: datasets/blogs/1171643.male.16.indUnk.Scorpio.xml
#   inflating: datasets/blogs/1173156.male.24.indUnk.Virgo.xml
#   inflating: datasets/blogs/1174200.male.17.indUnk.Libra.xml
#   inflating: datasets/blogs/11762.female.25.Student.Aries.xml
#   inflating: datasets/blogs/1178497.female.23.indUnk.Libra.xml
#   inflating: datasets/blogs/1178991.male.24.Technology.Virgo.xml
#   inflating: datasets/blogs/1180158.male.23.Consulting.Gemini.xml
#   inflating: datasets/blogs/1180573.female.26.Education.Sagittarius.xml
#   inflating: datasets/blogs/1183666.male.23.Internet.Aries.xml
#   inflating: datasets/blogs/1184801.male.23.Internet.Aries.xml
#   inflating: datasets/blogs/1185193.female.17.Student.Leo.xml
#   inflating: datasets/blogs/1187430.male.23.Internet.Capricorn.xml
#   inflating: datasets/blogs/118791.male.33.Internet.Virgo.xml
#   inflating: datasets/blogs/1188176.female.35.Education.Leo.xml
#   inflating: datasets/blogs/1190695.male.16.Student.Virgo.xml
#   inflating: datasets/blogs/1192293.male.25.Student.Cancer.xml
#   inflating: datasets/blogs/1193364.female.16.indUnk.Aries.xml
#   inflating: datasets/blogs/1194367.female.17.Law.Scorpio.xml
#   inflating: datasets/blogs/1195073.female.15.Student.Libra.xml
#   inflating: datasets/blogs/1196077.male.36.Communications-Media.Taurus.xml
#   inflating: datasets/blogs/1196970.male.16.indUnk.Sagittarius.xml
#   inflating: datasets/blogs/1197086.male.16.Student.Aries.xml
#   inflating: datasets/blogs/1197361.female.34.indUnk.Taurus.xml
#   inflating: datasets/blogs/1197937.female.23.Student.Scorpio.xml
#   inflating: datasets/blogs/1198592.female.24.Accounting.Pisces.xml
#   inflating: datasets/blogs/1199195.male.26.LawEnforcement-Security.Taurus.xml
#   inflating: datasets/blogs/1199948.male.16.indUnk.Libra.xml
#   inflating: datasets/blogs/1202874.male.16.Student.Capricorn.xml
#   inflating: datasets/blogs/1203229.male.24.Internet.Scorpio.xml
#   inflating: datasets/blogs/1204495.male.17.Student.Leo.xml
#   inflating: datasets/blogs/1205193.female.15.indUnk.Scorpio.xml
#   inflating: datasets/blogs/1207055.male.15.Arts.Aquarius.xml
#   inflating: datasets/blogs/1207422.female.40.Law.Gemini.xml
#   inflating: datasets/blogs/1208187.male.17.indUnk.Pisces.xml
#   inflating: datasets/blogs/1208423.male.23.Engineering.Aries.xml
#   inflating: datasets/blogs/1209241.male.25.Government.Virgo.xml
#   inflating: datasets/blogs/1209613.female.35.indUnk.Capricorn.xml
#   inflating: datasets/blogs/1209865.female.33.Architecture.Virgo.xml
#   inflating: datasets/blogs/1211557.male.16.Student.Virgo.xml
#   inflating: datasets/blogs/1211653.male.24.BusinessServices.Taurus.xml
#   inflating: datasets/blogs/1214462.male.37.indUnk.Virgo.xml
#   inflating: datasets/blogs/1216517.male.24.Education.Leo.xml
#   inflating: datasets/blogs/1217528.male.26.Advertising.Libra.xml
#   inflating: datasets/blogs/1217864.male.24.Non-Profit.Virgo.xml
#   inflating: datasets/blogs/1220898.male.34.indUnk.Taurus.xml
#   inflating: datasets/blogs/1221843.male.24.indUnk.Taurus.xml
#   inflating: datasets/blogs/122217.male.37.indUnk.Leo.xml
#   inflating: datasets/blogs/1222749.male.37.indUnk.Capricorn.xml
#   inflating: datasets/blogs/1223044.male.16.indUnk.Sagittarius.xml
#   inflating: datasets/blogs/1223561.male.23.Engineering.Cancer.xml
#   inflating: datasets/blogs/1224894.female.25.Student.Sagittarius.xml
#   inflating: datasets/blogs/1225020.female.16.HumanResources.Scorpio.xml
#   inflating: datasets/blogs/1225595.female.16.indUnk.Virgo.xml
#   inflating: datasets/blogs/1225881.male.17.Internet.Scorpio.xml
#   inflating: datasets/blogs/1226756.male.23.Technology.Leo.xml
#   inflating: datasets/blogs/1229858.male.24.indUnk.Leo.xml
#   inflating: datasets/blogs/1230289.female.24.Internet.Aries.xml
#   inflating: datasets/blogs/1231280.male.23.Student.Libra.xml
#   inflating: datasets/blogs/1231380.male.15.indUnk.Aquarius.xml
#   inflating: datasets/blogs/1231400.female.24.indUnk.Cancer.xml
#   inflating: datasets/blogs/1231733.female.24.Communications-Media.Cancer.xml
#   inflating: datasets/blogs/1232234.female.23.Communications-Media.Taurus.xml
#   inflating: datasets/blogs/1232458.female.38.indUnk.Cancer.xml
#   inflating: datasets/blogs/1233335.male.25.BusinessServices.Sagittarius.xml
#   inflating: datasets/blogs/1233687.male.35.Consulting.Aquarius.xml
#   inflating: datasets/blogs/1233897.male.17.Technology.Virgo.xml
#   inflating: datasets/blogs/1233956.female.17.indUnk.Libra.xml
#   inflating: datasets/blogs/1234212.male.27.indUnk.Taurus.xml
#   inflating: datasets/blogs/1234631.female.17.indUnk.Aquarius.xml
#   inflating: datasets/blogs/1234709.female.17.Student.Leo.xml
#   inflating: datasets/blogs/123532.male.39.Advertising.Aries.xml
#   inflating: datasets/blogs/1236636.male.24.Arts.Cancer.xml
#   inflating: datasets/blogs/1237310.male.38.Arts.Taurus.xml
#   inflating: datasets/blogs/1238294.female.33.indUnk.Leo.xml
#   inflating: datasets/blogs/1238388.male.17.Student.Cancer.xml
#   inflating: datasets/blogs/1239610.male.17.indUnk.Scorpio.xml
#   inflating: datasets/blogs/1240274.male.23.Communications-Media.Gemini.xml
#   inflating: datasets/blogs/1240631.male.41.Communications-Media.Libra.xml
#   inflating: datasets/blogs/1241231.male.37.Technology.Aries.xml
#   inflating: datasets/blogs/1241488.female.24.Publishing.Aries.xml
#   inflating: datasets/blogs/1241641.male.17.Student.Capricorn.xml
#   inflating: datasets/blogs/1242619.female.15.Arts.Capricorn.xml
#   inflating: datasets/blogs/1242759.female.16.Arts.Aquarius.xml
#   inflating: datasets/blogs/1244732.female.15.indUnk.Leo.xml
#   inflating: datasets/blogs/1245629.male.23.Technology.Gemini.xml
#   inflating: datasets/blogs/1245805.male.26.indUnk.Gemini.xml
#   inflating: datasets/blogs/1246193.male.17.Student.Gemini.xml
#   inflating: datasets/blogs/1246850.male.33.Internet.Capricorn.xml
#   inflating: datasets/blogs/1247134.male.25.Transportation.Cancer.xml
#   inflating: datasets/blogs/1248360.male.42.indUnk.Gemini.xml
#   inflating: datasets/blogs/1250730.male.26.indUnk.Cancer.xml
#   inflating: datasets/blogs/1251358.female.23.indUnk.Virgo.xml
#   inflating: datasets/blogs/1252171.male.14.Student.Sagittarius.xml
#   inflating: datasets/blogs/1252620.female.16.Fashion.Pisces.xml
#   inflating: datasets/blogs/1253219.female.27.indUnk.Sagittarius.xml
#   inflating: datasets/blogs/1254400.male.34.Religion.Leo.xml
#   inflating: datasets/blogs/1255416.male.17.Student.Taurus.xml
#   inflating: datasets/blogs/1255453.male.17.Consulting.Aquarius.xml
#   inflating: datasets/blogs/1255893.male.14.Student.Leo.xml
#   inflating: datasets/blogs/1256321.female.25.indUnk.Leo.xml
#   inflating: datasets/blogs/1258907.female.15.Student.Taurus.xml
#   inflating: datasets/blogs/1259041.female.17.Non-Profit.Taurus.xml
#   inflating: datasets/blogs/1259179.female.15.Student.Libra.xml
#   inflating: datasets/blogs/1261185.male.25.Technology.Sagittarius.xml
#   inflating: datasets/blogs/1261450.male.27.Internet.Aquarius.xml
#   inflating: datasets/blogs/1261679.female.16.indUnk.Gemini.xml
#   inflating: datasets/blogs/1262059.male.16.Student.Leo.xml
#   inflating: datasets/blogs/1263465.male.16.Technology.Scorpio.xml
#   inflating: datasets/blogs/1263794.female.17.Student.Cancer.xml
#   inflating: datasets/blogs/1264160.male.23.Arts.Pisces.xml
#   inflating: datasets/blogs/1266177.male.38.Internet.Taurus.xml
#   inflating: datasets/blogs/1266795.female.16.Student.Taurus.xml
#   inflating: datasets/blogs/1266843.female.24.Communications-Media.Pisces.xml
#   inflating: datasets/blogs/1266861.male.23.Non-Profit.Scorpio.xml
#   inflating: datasets/blogs/1267773.male.24.Student.Pisces.xml
#   inflating: datasets/blogs/1268682.male.35.indUnk.Pisces.xml
#   inflating: datasets/blogs/1269873.male.39.indUnk.Aquarius.xml
#   inflating: datasets/blogs/1270372.female.33.Manufacturing.Aries.xml
#   inflating: datasets/blogs/1270648.female.23.indUnk.Scorpio.xml
#   inflating: datasets/blogs/1273229.male.25.Internet.Cancer.xml
#   inflating: datasets/blogs/1273538.male.23.Advertising.Taurus.xml
#   inflating: datasets/blogs/1274152.female.34.indUnk.Scorpio.xml
#   inflating: datasets/blogs/1274171.male.36.indUnk.Gemini.xml
#   inflating: datasets/blogs/1274353.female.17.Student.Leo.xml
#   inflating: datasets/blogs/1274564.female.40.Internet.Sagittarius.xml
#   inflating: datasets/blogs/1274852.female.27.indUnk.Pisces.xml
#   inflating: datasets/blogs/1274993.male.44.indUnk.Gemini.xml
#   inflating: datasets/blogs/1276007.male.44.indUnk.Libra.xml
#   inflating: datasets/blogs/1277039.male.33.Government.Sagittarius.xml
#   inflating: datasets/blogs/1278138.female.26.Education.Pisces.xml
#   inflating: datasets/blogs/1279026.male.16.indUnk.Virgo.xml
#   inflating: datasets/blogs/1279436.male.34.indUnk.Pisces.xml
#   inflating: datasets/blogs/1280497.male.26.Technology.Taurus.xml
#   inflating: datasets/blogs/1281160.male.24.Technology.Sagittarius.xml
#   inflating: datasets/blogs/1283349.male.16.Student.Aries.xml
#   inflating: datasets/blogs/1283465.female.24.indUnk.Leo.xml
#   inflating: datasets/blogs/1284157.female.16.Student.Scorpio.xml
#   inflating: datasets/blogs/1284564.female.16.indUnk.Pisces.xml
#   inflating: datasets/blogs/1284681.male.25.Tourism.Gemini.xml
#   inflating: datasets/blogs/1284920.female.15.indUnk.Virgo.xml
#   inflating: datasets/blogs/1286861.female.24.Student.Cancer.xml
#   inflating: datasets/blogs/1288068.female.23.Education.Sagittarius.xml
#   inflating: datasets/blogs/1288281.female.27.Law.Aries.xml
#   inflating: datasets/blogs/1288571.male.26.Technology.Leo.xml
#   inflating: datasets/blogs/1289910.male.17.indUnk.Scorpio.xml
#   inflating: datasets/blogs/1290874.female.24.Non-Profit.Taurus.xml
#   inflating: datasets/blogs/129253.female.26.HumanResources.Cancer.xml
#   inflating: datasets/blogs/1292625.female.14.indUnk.Taurus.xml
#   inflating: datasets/blogs/1293280.male.25.Automotive.Cancer.xml
#   inflating: datasets/blogs/1293340.male.24.indUnk.Pisces.xml
#   inflating: datasets/blogs/1295657.female.23.Publishing.Scorpio.xml
#   inflating: datasets/blogs/1295671.female.26.Education.Virgo.xml
#   inflating: datasets/blogs/1295754.female.47.indUnk.Gemini.xml
#   inflating: datasets/blogs/1295794.female.26.indUnk.Sagittarius.xml
#   inflating: datasets/blogs/1296081.female.45.Technology.Virgo.xml
#   inflating: datasets/blogs/1296098.male.24.Sports-Recreation.Leo.xml
#   inflating: datasets/blogs/1296370.female.13.indUnk.Leo.xml
#   inflating: datasets/blogs/1296542.female.27.indUnk.Pisces.xml
#   inflating: datasets/blogs/1297806.female.23.indUnk.Aquarius.xml
#   inflating: datasets/blogs/1298624.male.25.Technology.Aries.xml
#   inflating: datasets/blogs/1298865.female.39.indUnk.Aquarius.xml
#   inflating: datasets/blogs/1302378.female.24.indUnk.Sagittarius.xml
#   inflating: datasets/blogs/1302874.male.46.indUnk.Leo.xml
#   inflating: datasets/blogs/1304142.female.17.indUnk.Pisces.xml
#   inflating: datasets/blogs/1304379.female.16.Student.Leo.xml
#   inflating: datasets/blogs/1304830.female.14.Education.Libra.xml
#   inflating: datasets/blogs/1305545.male.34.indUnk.Aquarius.xml
#   inflating: datasets/blogs/1306027.female.16.Student.Pisces.xml
#   inflating: datasets/blogs/1306088.male.27.indUnk.Sagittarius.xml
#   inflating: datasets/blogs/1306985.female.26.Telecommunications.Leo.xml
#   inflating: datasets/blogs/1307203.female.23.Student.Aries.xml
#   inflating: datasets/blogs/1308633.male.17.indUnk.Cancer.xml
#   inflating: datasets/blogs/1308868.male.26.Communications-Media.Cancer.xml
#   inflating: datasets/blogs/1309251.male.23.Technology.Libra.xml
#   inflating: datasets/blogs/1310522.female.26.Communications-Media.Sagittarius.xml
#   inflating: datasets/blogs/1311927.female.23.Arts.Aries.xml
#   inflating: datasets/blogs/1315210.male.23.Student.Aries.xml
#   inflating: datasets/blogs/1315669.female.23.Student.Virgo.xml
#   inflating: datasets/blogs/1316364.female.24.Student.Cancer.xml
#   inflating: datasets/blogs/1316855.male.25.Arts.Sagittarius.xml
#   inflating: datasets/blogs/1317513.male.17.Arts.Scorpio.xml
#   inflating: datasets/blogs/1317518.female.23.Marketing.Leo.xml
#   inflating: datasets/blogs/1319486.female.15.Student.Virgo.xml
#   inflating: datasets/blogs/1320783.male.25.Telecommunications.Aquarius.xml
#   inflating: datasets/blogs/1322112.male.34.indUnk.Capricorn.xml
#   inflating: datasets/blogs/1325355.female.26.indUnk.Cancer.xml
#   inflating: datasets/blogs/1325536.female.16.Student.Virgo.xml
#   inflating: datasets/blogs/1325807.female.25.indUnk.Pisces.xml
#   inflating: datasets/blogs/1325894.female.17.indUnk.Cancer.xml
#   inflating: datasets/blogs/132808.male.24.Technology.Gemini.xml
#   inflating: datasets/blogs/1328709.male.25.indUnk.Gemini.xml
#   inflating: datasets/blogs/132894.female.26.indUnk.Aries.xml
#   inflating: datasets/blogs/1329603.male.16.Student.Libra.xml
#   inflating: datasets/blogs/1329752.male.24.Technology.Taurus.xml
#   inflating: datasets/blogs/1330002.male.13.indUnk.Sagittarius.xml
#   inflating: datasets/blogs/1330888.female.36.indUnk.Pisces.xml
#   inflating: datasets/blogs/1334172.male.24.indUnk.Sagittarius.xml
#   inflating: datasets/blogs/1334247.female.17.Student.Libra.xml
#   inflating: datasets/blogs/1334361.female.15.indUnk.Libra.xml
#   inflating: datasets/blogs/1334509.female.23.Accounting.Taurus.xml
#   inflating: datasets/blogs/1335327.male.27.indUnk.Gemini.xml
#   inflating: datasets/blogs/1335479.male.37.Religion.Cancer.xml
#   inflating: datasets/blogs/1335883.male.27.Arts.Libra.xml
#   inflating: datasets/blogs/133604.female.23.indUnk.Capricorn.xml
#   inflating: datasets/blogs/1336804.female.24.Law.Taurus.xml
#   inflating: datasets/blogs/1337805.female.17.Student.Aquarius.xml
#   inflating: datasets/blogs/1338710.male.25.Arts.Libra.xml
#   inflating: datasets/blogs/1340343.female.16.Student.Taurus.xml
#   inflating: datasets/blogs/1340794.male.26.Science.Scorpio.xml
#   inflating: datasets/blogs/1341658.male.15.Student.Cancer.xml
#   inflating: datasets/blogs/1341988.female.24.Marketing.Cancer.xml
#   inflating: datasets/blogs/1343387.female.23.indUnk.Aries.xml
#   inflating: datasets/blogs/1343573.male.25.indUnk.Libra.xml
#   inflating: datasets/blogs/1345466.female.24.Communications-Media.Aquarius.xml
#   inflating: datasets/blogs/1347923.male.36.Advertising.Taurus.xml
#   inflating: datasets/blogs/1348691.female.36.Consulting.Gemini.xml
#   inflating: datasets/blogs/1350027.female.16.Student.Scorpio.xml
#   inflating: datasets/blogs/1350461.male.25.indUnk.Cancer.xml
#   inflating: datasets/blogs/1351689.male.37.indUnk.Leo.xml
#   inflating: datasets/blogs/1352717.female.36.Education.Sagittarius.xml
#   inflating: datasets/blogs/1352859.female.26.indUnk.Sagittarius.xml
#   inflating: datasets/blogs/1355143.male.23.Student.Gemini.xml
#   inflating: datasets/blogs/1357293.female.25.BusinessServices.Aries.xml
#   inflating: datasets/blogs/1357961.female.27.indUnk.Gemini.xml
#   inflating: datasets/blogs/135888.male.23.Banking.Libra.xml
#   inflating: datasets/blogs/1359229.male.17.Education.Taurus.xml
#   inflating: datasets/blogs/1359631.male.26.Internet.Cancer.xml
#   inflating: datasets/blogs/1360300.male.34.Tourism.Libra.xml
#   inflating: datasets/blogs/1360750.female.35.Arts.Leo.xml
#   inflating: datasets/blogs/1361398.female.26.indUnk.Cancer.xml
#   inflating: datasets/blogs/1362051.female.16.Tourism.Aries.xml
#   inflating: datasets/blogs/1362978.female.27.Education.Leo.xml
#   inflating: datasets/blogs/1363208.male.25.Technology.Aquarius.xml
#   inflating: datasets/blogs/1363719.female.36.Education.Taurus.xml
#   inflating: datasets/blogs/1364511.female.27.Arts.Leo.xml
#   inflating: datasets/blogs/1365227.male.27.indUnk.Taurus.xml
#   inflating: datasets/blogs/1365296.male.25.Student.Taurus.xml
#   inflating: datasets/blogs/1365875.female.27.indUnk.Gemini.xml
#   inflating: datasets/blogs/1366447.male.34.indUnk.Libra.xml
#   inflating: datasets/blogs/1366896.female.17.Student.Aries.xml
#   inflating: datasets/blogs/1366984.female.25.Technology.Aries.xml
#   inflating: datasets/blogs/1369564.male.16.Non-Profit.Aquarius.xml
#   inflating: datasets/blogs/1371155.female.23.Education.Scorpio.xml
#   inflating: datasets/blogs/1373040.female.40.indUnk.Cancer.xml
#   inflating: datasets/blogs/1374061.male.34.indUnk.Gemini.xml
#   inflating: datasets/blogs/1374867.female.13.indUnk.Aquarius.xml
#   inflating: datasets/blogs/137626.male.24.indUnk.Gemini.xml
#   inflating: datasets/blogs/1377580.female.24.indUnk.Capricorn.xml
#   inflating: datasets/blogs/1378761.male.16.Student.Libra.xml
#   inflating: datasets/blogs/1379288.female.35.HumanResources.Aries.xml
#   inflating: datasets/blogs/1380515.male.40.indUnk.Aquarius.xml
#   inflating: datasets/blogs/1380619.male.34.indUnk.Taurus.xml
#   inflating: datasets/blogs/1381293.male.16.Internet.Sagittarius.xml
#   inflating: datasets/blogs/1381825.female.16.indUnk.Scorpio.xml
#   inflating: datasets/blogs/1382294.female.16.indUnk.Aries.xml
#   inflating: datasets/blogs/1382785.male.23.indUnk.Scorpio.xml
#   inflating: datasets/blogs/1383163.male.26.Technology.Cancer.xml
#   inflating: datasets/blogs/1383289.female.14.Student.Libra.xml
#   inflating: datasets/blogs/1384161.male.25.Communications-Media.Scorpio.xml
#   inflating: datasets/blogs/1386800.female.45.Non-Profit.Pisces.xml
#   inflating: datasets/blogs/1388402.female.15.Student.Capricorn.xml
#   inflating: datasets/blogs/1390302.female.26.Student.Leo.xml
#   inflating: datasets/blogs/1390907.female.37.Telecommunications.Leo.xml
#   inflating: datasets/blogs/1391421.female.41.indUnk.Pisces.xml
#   inflating: datasets/blogs/1391636.female.26.Religion.Cancer.xml
#   inflating: datasets/blogs/1392111.female.34.indUnk.Leo.xml
#   inflating: datasets/blogs/1392379.female.25.indUnk.Leo.xml
#   inflating: datasets/blogs/1392567.female.24.indUnk.Cancer.xml
#   inflating: datasets/blogs/1392976.male.23.indUnk.Scorpio.xml
#   inflating: datasets/blogs/1393814.female.13.indUnk.Gemini.xml
#   inflating: datasets/blogs/1394735.male.38.Technology.Capricorn.xml
#   inflating: datasets/blogs/1395849.female.23.Non-Profit.Leo.xml
#   inflating: datasets/blogs/1395900.male.27.indUnk.Taurus.xml
#   inflating: datasets/blogs/1396260.female.23.indUnk.Cancer.xml
#   inflating: datasets/blogs/1397914.male.41.indUnk.Sagittarius.xml
#   inflating: datasets/blogs/1399489.male.17.Student.Virgo.xml
#   inflating: datasets/blogs/1400059.male.23.Education.Pisces.xml
#   inflating: datasets/blogs/1400705.male.26.Communications-Media.Capricorn.xml
#   inflating: datasets/blogs/1401178.female.23.Student.Pisces.xml
#   inflating: datasets/blogs/1401402.female.23.Student.Capricorn.xml
#   inflating: datasets/blogs/1401460.female.27.Communications-Media.Libra.xml
#   inflating: datasets/blogs/1401816.male.40.indUnk.Pisces.xml
#   inflating: datasets/blogs/1402277.female.23.Agriculture.Pisces.xml
#   inflating: datasets/blogs/1403830.male.15.Student.Taurus.xml
#   inflating: datasets/blogs/1404145.male.17.Religion.Cancer.xml
#   inflating: datasets/blogs/1404301.female.24.Student.Libra.xml
#   inflating: datasets/blogs/1405024.female.24.indUnk.Cancer.xml
#   inflating: datasets/blogs/1405766.male.24.HumanResources.Scorpio.xml
#   inflating: datasets/blogs/1405870.female.26.indUnk.Cancer.xml
#   inflating: datasets/blogs/1406453.female.17.Student.Capricorn.xml
#   inflating: datasets/blogs/1406988.male.23.Telecommunications.Sagittarius.xml
#   inflating: datasets/blogs/1407084.male.17.Student.Leo.xml
#   inflating: datasets/blogs/1407268.male.23.indUnk.Taurus.xml
#   inflating: datasets/blogs/1409146.female.27.Communications-Media.Libra.xml
#   inflating: datasets/blogs/1409492.female.40.Technology.Taurus.xml
#   inflating: datasets/blogs/1409523.male.17.Student.Scorpio.xml
#   inflating: datasets/blogs/1410011.female.16.indUnk.Libra.xml
#   inflating: datasets/blogs/1412504.male.33.Internet.Taurus.xml
#   inflating: datasets/blogs/1413196.male.24.Engineering.Pisces.xml
#   inflating: datasets/blogs/1414354.male.24.Non-Profit.Leo.xml
#   inflating: datasets/blogs/1415200.female.15.Student.Libra.xml
#   inflating: datasets/blogs/1416208.female.23.BusinessServices.Sagittarius.xml
#   inflating: datasets/blogs/1416900.male.25.indUnk.Cancer.xml
#   inflating: datasets/blogs/1417015.male.15.Student.Libra.xml
#   inflating: datasets/blogs/1417798.female.35.indUnk.Scorpio.xml
#   inflating: datasets/blogs/141799.female.25.Advertising.Pisces.xml
#   inflating: datasets/blogs/1418167.female.17.Student.Gemini.xml
#   inflating: datasets/blogs/1420041.male.17.indUnk.Cancer.xml
#   inflating: datasets/blogs/1421166.male.16.Student.Leo.xml
#   inflating: datasets/blogs/1423400.male.17.Student.Virgo.xml
#   inflating: datasets/blogs/1425758.male.24.Technology.Capricorn.xml
#   inflating: datasets/blogs/1425881.female.14.indUnk.Sagittarius.xml
#   inflating: datasets/blogs/1425932.male.25.Publishing.Aries.xml
#   inflating: datasets/blogs/1427070.female.25.indUnk.Gemini.xml
#   inflating: datasets/blogs/1427339.female.17.indUnk.Libra.xml
#   inflating: datasets/blogs/1427811.male.46.Education.Virgo.xml
#   inflating: datasets/blogs/1428082.male.38.Communications-Media.Leo.xml
#   inflating: datasets/blogs/1428697.male.33.indUnk.Virgo.xml
#   inflating: datasets/blogs/1428880.male.27.indUnk.Aquarius.xml
#   inflating: datasets/blogs/1429060.male.17.Student.Cancer.xml
#   inflating: datasets/blogs/1429393.female.35.indUnk.Aries.xml
#   inflating: datasets/blogs/1429767.male.15.Student.Virgo.xml
#   inflating: datasets/blogs/1432215.female.35.Communications-Media.Aries.xml
#   inflating: datasets/blogs/1432406.female.16.indUnk.Gemini.xml
#   inflating: datasets/blogs/1432868.male.16.Student.Scorpio.xml
#   inflating: datasets/blogs/1434608.male.27.Internet.Sagittarius.xml
#   inflating: datasets/blogs/1435222.female.27.indUnk.Cancer.xml
#   inflating: datasets/blogs/1435600.male.16.Student.Aries.xml
#   inflating: datasets/blogs/1436059.female.15.Education.Gemini.xml
#   inflating: datasets/blogs/1436696.female.23.Agriculture.Capricorn.xml
#   inflating: datasets/blogs/143781.female.25.Education.Aries.xml
#   inflating: datasets/blogs/1438488.female.26.indUnk.Leo.xml
#   inflating: datasets/blogs/1438491.male.16.Agriculture.Aries.xml
#   inflating: datasets/blogs/1438661.female.16.indUnk.Virgo.xml
#   inflating: datasets/blogs/1439099.female.27.Education.Cancer.xml
#   inflating: datasets/blogs/1440291.female.23.Accounting.Pisces.xml
#   inflating: datasets/blogs/1442904.male.39.indUnk.Virgo.xml
#   inflating: datasets/blogs/1443644.male.16.Student.Pisces.xml
#   inflating: datasets/blogs/1444118.female.41.Law.Leo.xml
#   inflating: datasets/blogs/1444263.female.17.Arts.Sagittarius.xml
#   inflating: datasets/blogs/1444311.male.23.Education.Aquarius.xml
#   inflating: datasets/blogs/1445315.female.23.indUnk.Scorpio.xml
#   inflating: datasets/blogs/1445734.male.26.Technology.Leo.xml
#   inflating: datasets/blogs/1446030.female.17.Student.Aquarius.xml
#   inflating: datasets/blogs/1449141.male.43.Education.Aquarius.xml
#   inflating: datasets/blogs/1450156.female.37.indUnk.Leo.xml
#   inflating: datasets/blogs/1450587.female.15.Arts.Aquarius.xml
#   inflating: datasets/blogs/1450960.female.24.Fashion.Pisces.xml
#   inflating: datasets/blogs/1451285.female.25.indUnk.Taurus.xml
#   inflating: datasets/blogs/1452076.female.15.Student.Sagittarius.xml
#   inflating: datasets/blogs/1452877.male.17.indUnk.Cancer.xml
#   inflating: datasets/blogs/1453177.female.26.indUnk.Taurus.xml
#   inflating: datasets/blogs/1455561.male.17.Student.Scorpio.xml
#   inflating: datasets/blogs/1456646.female.24.indUnk.Aquarius.xml
#   inflating: datasets/blogs/1461221.female.27.Marketing.Libra.xml
#   inflating: datasets/blogs/1461401.female.16.Student.Scorpio.xml
#   inflating: datasets/blogs/1461773.male.25.Engineering.Virgo.xml
#   inflating: datasets/blogs/1461990.female.17.indUnk.Libra.xml
#   inflating: datasets/blogs/1462207.female.26.Science.Cancer.xml
#   inflating: datasets/blogs/1463590.female.24.Education.Capricorn.xml
#   inflating: datasets/blogs/1463769.male.23.indUnk.Cancer.xml
#   inflating: datasets/blogs/1464008.male.23.Publishing.Capricorn.xml
#   inflating: datasets/blogs/1464036.male.24.Technology.Cancer.xml
#   inflating: datasets/blogs/1464756.female.23.Military.Pisces.xml
#   inflating: datasets/blogs/1464983.male.24.indUnk.Cancer.xml
#   inflating: datasets/blogs/1464999.male.23.Student.Leo.xml
#   inflating: datasets/blogs/1465987.female.33.indUnk.Aquarius.xml
#   inflating: datasets/blogs/1466700.male.24.Arts.Aries.xml
#   inflating: datasets/blogs/1468613.male.26.Technology.Taurus.xml
#   inflating: datasets/blogs/1469021.male.34.indUnk.Libra.xml
#   inflating: datasets/blogs/1470319.female.26.Museums-Libraries.Libra.xml
#   inflating: datasets/blogs/1472026.female.47.Arts.Sagittarius.xml
#   inflating: datasets/blogs/1472294.female.16.Student.Leo.xml
#   inflating: datasets/blogs/1472662.male.23.Internet.Aries.xml
#   inflating: datasets/blogs/1472995.female.27.indUnk.Aries.xml
#   inflating: datasets/blogs/1473902.female.25.indUnk.Pisces.xml
#   inflating: datasets/blogs/1474169.male.23.Tourism.Gemini.xml
#   inflating: datasets/blogs/1474573.female.23.Student.Leo.xml
#   inflating: datasets/blogs/1476037.female.16.indUnk.Virgo.xml
#   inflating: datasets/blogs/1476382.male.33.Publishing.Gemini.xml
#   inflating: datasets/blogs/1476558.female.24.Law.Pisces.xml
#   inflating: datasets/blogs/1476840.female.33.Museums-Libraries.Virgo.xml
#   inflating: datasets/blogs/1477098.female.17.Marketing.Sagittarius.xml
#   inflating: datasets/blogs/1477179.female.23.Education.Leo.xml
#   inflating: datasets/blogs/1477224.male.24.Non-Profit.Leo.xml
#   inflating: datasets/blogs/1477618.female.33.indUnk.Cancer.xml
#   inflating: datasets/blogs/1478602.male.23.Communications-Media.Libra.xml
#   inflating: datasets/blogs/1478632.male.17.Student.Leo.xml
#   inflating: datasets/blogs/1479989.female.25.indUnk.Sagittarius.xml
#   inflating: datasets/blogs/1480689.female.17.Student.Virgo.xml
#   inflating: datasets/blogs/1482060.male.17.Student.Cancer.xml
#   inflating: datasets/blogs/1484232.female.23.BusinessServices.Leo.xml
#   inflating: datasets/blogs/1485746.male.39.Technology.Scorpio.xml
#   inflating: datasets/blogs/1485806.male.24.Technology.Capricorn.xml
#   inflating: datasets/blogs/148638.male.36.Technology.Sagittarius.xml
#   inflating: datasets/blogs/1486619.male.35.Technology.Taurus.xml
#   inflating: datasets/blogs/1487795.male.17.indUnk.Gemini.xml
#   inflating: datasets/blogs/1488330.male.17.Non-Profit.Pisces.xml
#   inflating: datasets/blogs/1488629.female.34.indUnk.Libra.xml
#   inflating: datasets/blogs/1491593.male.27.indUnk.Cancer.xml
#   inflating: datasets/blogs/1492818.female.47.Arts.Aries.xml
#   inflating: datasets/blogs/1493200.male.39.indUnk.Aries.xml
#   inflating: datasets/blogs/1493787.male.27.indUnk.Gemini.xml
#   inflating: datasets/blogs/1493879.male.24.Transportation.Virgo.xml
#   inflating: datasets/blogs/1495706.male.24.Student.Cancer.xml
#   inflating: datasets/blogs/1496067.female.17.indUnk.Libra.xml
#   inflating: datasets/blogs/1496664.female.35.Arts.Sagittarius.xml
#   inflating: datasets/blogs/1496806.male.33.Publishing.Leo.xml
#   inflating: datasets/blogs/1498597.male.17.Student.Pisces.xml
#   inflating: datasets/blogs/1498713.female.23.Non-Profit.Sagittarius.xml
#   inflating: datasets/blogs/1499735.female.24.indUnk.Pisces.xml
#   inflating: datasets/blogs/1500723.male.23.Technology.Cancer.xml
#   inflating: datasets/blogs/1502295.female.33.Government.Capricorn.xml
#   inflating: datasets/blogs/1502896.female.25.Consulting.Pisces.xml
#   inflating: datasets/blogs/1503551.male.27.Education.Sagittarius.xml
#   inflating: datasets/blogs/1503737.male.26.indUnk.Pisces.xml
#   inflating: datasets/blogs/1504395.female.27.indUnk.Aries.xml
#   inflating: datasets/blogs/1506385.female.27.Internet.Gemini.xml
#   inflating: datasets/blogs/1507424.male.35.Arts.Cancer.xml
#   inflating: datasets/blogs/1509245.female.16.indUnk.Pisces.xml
#   inflating: datasets/blogs/151025.female.24.HumanResources.Pisces.xml
#   inflating: datasets/blogs/1510754.male.24.Internet.Aries.xml
#   inflating: datasets/blogs/1512157.female.15.indUnk.Sagittarius.xml
#   inflating: datasets/blogs/1512689.female.23.indUnk.Pisces.xml
#   inflating: datasets/blogs/1515112.female.33.indUnk.Gemini.xml
#   inflating: datasets/blogs/1516660.male.17.Student.Cancer.xml
#   inflating: datasets/blogs/151688.male.27.Communications-Media.Cancer.xml
#   inflating: datasets/blogs/1516969.male.24.indUnk.Aquarius.xml
#   inflating: datasets/blogs/1517450.male.26.indUnk.Virgo.xml
#   inflating: datasets/blogs/1519254.male.24.indUnk.Libra.xml
#   inflating: datasets/blogs/152088.female.25.Communications-Media.Aquarius.xml
#   inflating: datasets/blogs/152151.female.23.Engineering.Libra.xml
#   inflating: datasets/blogs/1523484.male.15.Student.Aquarius.xml
#   inflating: datasets/blogs/1524664.female.23.Law.Capricorn.xml
#   inflating: datasets/blogs/1524959.female.17.indUnk.Pisces.xml
#   inflating: datasets/blogs/1525801.male.23.indUnk.Aries.xml
#   inflating: datasets/blogs/1526231.female.24.indUnk.Scorpio.xml
#   inflating: datasets/blogs/1526405.female.26.Education.Leo.xml
#   inflating: datasets/blogs/1527446.male.17.LawEnforcement-Security.Capricorn.xml
#   inflating: datasets/blogs/1531340.female.15.indUnk.Cancer.xml
#   inflating: datasets/blogs/1532204.male.23.Accounting.Scorpio.xml
#   inflating: datasets/blogs/1533236.female.27.indUnk.Scorpio.xml
#   inflating: datasets/blogs/1533422.female.14.Student.Cancer.xml
#   inflating: datasets/blogs/1534256.male.16.Student.Leo.xml
#   inflating: datasets/blogs/1534611.male.15.Student.Sagittarius.xml
#   inflating: datasets/blogs/1535244.male.17.Student.Virgo.xml
#   inflating: datasets/blogs/1535572.female.24.Publishing.Leo.xml
#   inflating: datasets/blogs/15365.female.34.indUnk.Cancer.xml
#   inflating: datasets/blogs/1537747.male.26.Arts.Taurus.xml
#   inflating: datasets/blogs/1538355.female.15.indUnk.Aquarius.xml
#   inflating: datasets/blogs/1538911.female.35.indUnk.Libra.xml
#   inflating: datasets/blogs/154141.male.24.Internet.Aries.xml
#   inflating: datasets/blogs/1543875.female.25.Education.Cancer.xml
#   inflating: datasets/blogs/1544534.female.17.indUnk.Aquarius.xml
#   inflating: datasets/blogs/1547685.male.14.Student.Leo.xml
#   inflating: datasets/blogs/1549052.male.16.Education.Scorpio.xml
#   inflating: datasets/blogs/1549103.female.23.Technology.Taurus.xml
#   inflating: datasets/blogs/1549532.female.24.Biotech.Scorpio.xml
#   inflating: datasets/blogs/1549616.male.27.Technology.Virgo.xml
#   inflating: datasets/blogs/1550279.male.17.Student.Sagittarius.xml
#   inflating: datasets/blogs/1550368.female.36.indUnk.Aquarius.xml
#   inflating: datasets/blogs/1550687.female.24.Communications-Media.Sagittarius.xml
#   inflating: datasets/blogs/1552033.male.43.Education.Taurus.xml
#   inflating: datasets/blogs/1552252.male.24.Science.Taurus.xml
#   inflating: datasets/blogs/1555267.male.35.Engineering.Aquarius.xml
#   inflating: datasets/blogs/155710.male.23.indUnk.Cancer.xml
#   inflating: datasets/blogs/1557658.male.37.Technology.Cancer.xml
#   inflating: datasets/blogs/1558100.male.23.Student.Libra.xml
#   inflating: datasets/blogs/1558288.female.15.Engineering.Taurus.xml
#   inflating: datasets/blogs/1561597.female.25.Fashion.Scorpio.xml
#   inflating: datasets/blogs/1561856.male.27.Engineering.Pisces.xml
#   inflating: datasets/blogs/1562200.female.23.Advertising.Cancer.xml
#   inflating: datasets/blogs/1563867.male.27.indUnk.Leo.xml
#   inflating: datasets/blogs/1564008.female.16.Sports-Recreation.Libra.xml
#   inflating: datasets/blogs/1564092.male.17.Student.Aries.xml
#   inflating: datasets/blogs/1564288.female.17.Transportation.Aries.xml
#   inflating: datasets/blogs/1566807.female.37.Education.Gemini.xml
#   inflating: datasets/blogs/1566821.female.25.indUnk.Taurus.xml
#   inflating: datasets/blogs/1567012.male.14.Student.Leo.xml
#   inflating: datasets/blogs/1567751.female.25.Education.Cancer.xml
#   inflating: datasets/blogs/1568659.male.33.Internet.Scorpio.xml
#   inflating: datasets/blogs/1570566.male.16.indUnk.Gemini.xml
#   inflating: datasets/blogs/1570719.male.26.Education.Libra.xml
#   inflating: datasets/blogs/1571041.male.26.Student.Taurus.xml
#   inflating: datasets/blogs/1571308.male.34.Communications-Media.Leo.xml
#   inflating: datasets/blogs/1572460.male.24.Student.Scorpio.xml
#   inflating: datasets/blogs/1576936.male.17.indUnk.Scorpio.xml
#   inflating: datasets/blogs/1578617.male.27.Communications-Media.Cancer.xml
#   inflating: datasets/blogs/1579923.male.15.indUnk.Virgo.xml
#   inflating: datasets/blogs/1580166.male.25.Engineering.Virgo.xml
#   inflating: datasets/blogs/1582428.male.37.Consulting.Capricorn.xml
#   inflating: datasets/blogs/1583261.female.16.Arts.Gemini.xml
#   inflating: datasets/blogs/1583560.female.24.Student.Sagittarius.xml
#   inflating: datasets/blogs/1584393.female.23.Student.Cancer.xml
#   inflating: datasets/blogs/1585532.male.16.Student.Libra.xml
#   inflating: datasets/blogs/1585689.female.25.indUnk.Capricorn.xml
#   inflating: datasets/blogs/1585928.female.16.Student.Scorpio.xml
#   inflating: datasets/blogs/1586126.male.15.Student.Capricorn.xml
#   inflating: datasets/blogs/1586479.male.17.Student.Virgo.xml
#   inflating: datasets/blogs/1586925.male.27.Banking.Aquarius.xml
#   inflating: datasets/blogs/1587910.female.16.indUnk.Aries.xml
#   inflating: datasets/blogs/1588678.male.13.Student.Scorpio.xml
#   inflating: datasets/blogs/1588876.female.15.Student.Leo.xml
#   inflating: datasets/blogs/1589546.male.41.Consulting.Virgo.xml
#   inflating: datasets/blogs/1589779.male.17.indUnk.Sagittarius.xml
#   inflating: datasets/blogs/1589923.male.26.Student.Aries.xml
#   inflating: datasets/blogs/1591337.male.16.Education.Taurus.xml
#   inflating: datasets/blogs/1591487.female.36.Technology.Aries.xml
#   inflating: datasets/blogs/1591821.male.24.indUnk.Virgo.xml
#   inflating: datasets/blogs/1591994.male.15.indUnk.Cancer.xml
#   inflating: datasets/blogs/1592012.male.17.indUnk.Aquarius.xml
# ...
#   inflating: datasets/blogs/764243.female.27.Internet.Virgo.xml
#   inflating: datasets/blogs/765488.male.25.Communications-Media.Virgo.xml
#   inflating: datasets/blogs/766556.female.34.indUnk.Sagittarius.xml
#   inflating: datasets/blogs/769066.male.40.indUnk.Leo.xml
#   inflating: datasets/blogs/769189.female.17.Student.Capricorn.xml
#   inflating: datasets/blogs/769349.male.34.Arts.Scorpio.xml
#   inflating: datasets/blogs/771794.male.23.indUnk.Aquarius.xml
#   inflating: datasets/blogs/772682.female.23.Arts.Libra.xml
#   inflating: datasets/blogs/773482.male.24.indUnk.Taurus.xml
#   inflating: datasets/blogs/775493.male.23.Accounting.Cancer.xml
#   inflating: datasets/blogs/776291.male.23.indUnk.Virgo.xml
#   inflating: datasets/blogs/776742.male.25.Engineering.Taurus.xml
#   inflating: datasets/blogs/778441.male.27.Technology.Libra.xml
#   inflating: datasets/blogs/778877.female.47.indUnk.Cancer.xml
#   inflating: datasets/blogs/780903.male.25.Student.Aquarius.xml
#   inflating: datasets/blogs/78196.female.35.indUnk.Aries.xml
#   inflating: datasets/blogs/782203.male.25.Technology.Virgo.xml
#   inflating: datasets/blogs/783193.female.15.Student.Capricorn.xml
#   inflating: datasets/blogs/786044.male.23.Technology.Scorpio.xml
#   inflating: datasets/blogs/786829.female.16.Student.Leo.xml
#   inflating: datasets/blogs/788235.female.35.Science.Aquarius.xml
#   inflating: datasets/blogs/788358.male.24.Arts.Libra.xml
#   inflating: datasets/blogs/788910.male.16.indUnk.Aries.xml
#   inflating: datasets/blogs/788927.male.16.Communications-Media.Scorpio.xml
#   inflating: datasets/blogs/789637.female.25.indUnk.Libra.xml
#   inflating: datasets/blogs/790559.female.34.Internet.Leo.xml
#   inflating: datasets/blogs/790651.male.33.Telecommunications.Aquarius.xml
#   inflating: datasets/blogs/791676.male.25.indUnk.Sagittarius.xml
#   inflating: datasets/blogs/791840.male.38.Student.Aries.xml
#   inflating: datasets/blogs/792049.male.17.indUnk.Aquarius.xml
#   inflating: datasets/blogs/792246.male.17.Student.Virgo.xml
#   inflating: datasets/blogs/792437.female.24.Education.Gemini.xml
#   inflating: datasets/blogs/792439.male.26.Student.Aquarius.xml
#   inflating: datasets/blogs/794223.female.23.Student.Aries.xml
#   inflating: datasets/blogs/794491.male.23.Arts.Sagittarius.xml
#   inflating: datasets/blogs/794646.female.17.indUnk.Aries.xml
#   inflating: datasets/blogs/795131.female.39.Technology.Scorpio.xml
#   inflating: datasets/blogs/796779.male.25.indUnk.Leo.xml
#   inflating: datasets/blogs/797269.female.15.Student.Libra.xml
#   inflating: datasets/blogs/798653.male.26.indUnk.Aquarius.xml
#   inflating: datasets/blogs/799191.female.25.indUnk.Libra.xml
#   inflating: datasets/blogs/799228.male.25.indUnk.Leo.xml
#   inflating: datasets/blogs/799700.female.26.indUnk.Gemini.xml
#   inflating: datasets/blogs/799760.male.26.indUnk.Cancer.xml
#   inflating: datasets/blogs/800231.female.15.Student.Virgo.xml
#   inflating: datasets/blogs/800873.male.27.Education.Aquarius.xml
#   inflating: datasets/blogs/801102.female.23.Advertising.Aquarius.xml
#   inflating: datasets/blogs/801180.male.36.Technology.Pisces.xml
#   inflating: datasets/blogs/801554.male.17.Student.Pisces.xml
#   inflating: datasets/blogs/801916.female.23.Advertising.Taurus.xml
#   inflating: datasets/blogs/805451.female.27.Education.Libra.xml
#   inflating: datasets/blogs/807398.female.27.indUnk.Sagittarius.xml
#   inflating: datasets/blogs/808099.female.26.indUnk.Cancer.xml
#   inflating: datasets/blogs/808956.female.25.Government.Aries.xml
#   inflating: datasets/blogs/813360.female.23.BusinessServices.Capricorn.xml
#   inflating: datasets/blogs/813893.female.17.indUnk.Taurus.xml
#   inflating: datasets/blogs/814486.male.26.Internet.Cancer.xml
#   inflating: datasets/blogs/815368.male.23.Student.Sagittarius.xml
#   inflating: datasets/blogs/815531.female.23.indUnk.Leo.xml
#   inflating: datasets/blogs/815748.male.16.Student.Leo.xml
#   inflating: datasets/blogs/817097.female.26.Student.Taurus.xml
#   inflating: datasets/blogs/8173.male.42.indUnk.Capricorn.xml
#   inflating: datasets/blogs/819785.male.23.Student.Taurus.xml
#   inflating: datasets/blogs/823125.male.43.indUnk.Aquarius.xml
#   inflating: datasets/blogs/823780.male.17.Education.Scorpio.xml
#   inflating: datasets/blogs/824183.female.38.indUnk.Scorpio.xml
#   inflating: datasets/blogs/824204.female.23.Student.Taurus.xml
#   inflating: datasets/blogs/825029.female.17.Student.Aries.xml
#   inflating: datasets/blogs/826407.male.25.Education.Pisces.xml
#   inflating: datasets/blogs/826496.male.26.Publishing.Cancer.xml
#   inflating: datasets/blogs/827534.female.33.indUnk.Sagittarius.xml
#   inflating: datasets/blogs/828046.male.25.Arts.Gemini.xml
#   inflating: datasets/blogs/828248.male.25.InvestmentBanking.Scorpio.xml
#   inflating: datasets/blogs/828778.male.23.Sports-Recreation.Sagittarius.xml
#   inflating: datasets/blogs/829324.male.26.Student.Aquarius.xml
#   inflating: datasets/blogs/831082.male.23.indUnk.Scorpio.xml
#   inflating: datasets/blogs/831233.male.16.indUnk.Taurus.xml
#   inflating: datasets/blogs/831241.female.40.indUnk.Cancer.xml
#   inflating: datasets/blogs/832265.male.27.Technology.Libra.xml
#   inflating: datasets/blogs/8349.male.24.Consulting.Cancer.xml
#   inflating: datasets/blogs/834914.male.24.indUnk.Aries.xml
#   inflating: datasets/blogs/837532.female.15.Student.Scorpio.xml
#   inflating: datasets/blogs/838162.male.25.Student.Capricorn.xml
#   inflating: datasets/blogs/841771.female.25.indUnk.Sagittarius.xml
#   inflating: datasets/blogs/841857.female.17.indUnk.Virgo.xml
#   inflating: datasets/blogs/843566.female.26.indUnk.Scorpio.xml
#   inflating: datasets/blogs/844074.female.25.indUnk.Gemini.xml
#   inflating: datasets/blogs/848630.female.23.indUnk.Cancer.xml
#   inflating: datasets/blogs/849453.female.39.Transportation.Leo.xml
#   inflating: datasets/blogs/851693.female.15.Student.Aquarius.xml
#   inflating: datasets/blogs/853190.female.35.Law.Pisces.xml
#   inflating: datasets/blogs/853818.male.39.BusinessServices.Leo.xml
#   inflating: datasets/blogs/854866.female.33.indUnk.Pisces.xml
#   inflating: datasets/blogs/854956.female.23.Student.Leo.xml
#   inflating: datasets/blogs/854992.female.17.Student.Aries.xml
#   inflating: datasets/blogs/855133.male.25.Communications-Media.Cancer.xml
#   inflating: datasets/blogs/85757.male.24.Marketing.Libra.xml
#   inflating: datasets/blogs/858436.female.15.Student.Scorpio.xml
#   inflating: datasets/blogs/860293.female.25.Law.Sagittarius.xml
#   inflating: datasets/blogs/861706.male.24.indUnk.Sagittarius.xml
#   inflating: datasets/blogs/862379.female.25.Science.Virgo.xml
#   inflating: datasets/blogs/863416.female.25.indUnk.Pisces.xml
#   inflating: datasets/blogs/864944.male.27.Technology.Aries.xml
#   inflating: datasets/blogs/865087.male.25.Internet.Sagittarius.xml
#   inflating: datasets/blogs/865721.female.24.BusinessServices.Virgo.xml
#   inflating: datasets/blogs/867406.male.36.Internet.Leo.xml
#   inflating: datasets/blogs/867772.female.16.Student.Taurus.xml
#   inflating: datasets/blogs/869292.male.34.Advertising.Sagittarius.xml
#   inflating: datasets/blogs/870139.female.24.Non-Profit.Gemini.xml
#   inflating: datasets/blogs/870741.female.17.indUnk.Sagittarius.xml
#   inflating: datasets/blogs/870843.male.17.Student.Sagittarius.xml
#   inflating: datasets/blogs/871501.female.27.Marketing.Gemini.xml
#   inflating: datasets/blogs/873288.female.23.Arts.Capricorn.xml
#   inflating: datasets/blogs/876950.male.26.Law.Scorpio.xml
#   inflating: datasets/blogs/877201.female.23.indUnk.Leo.xml
#   inflating: datasets/blogs/877254.female.27.indUnk.Aries.xml
#   inflating: datasets/blogs/878542.male.23.Technology.Leo.xml
#   inflating: datasets/blogs/878554.female.24.Accounting.Aquarius.xml
#   inflating: datasets/blogs/880351.male.16.Arts.Pisces.xml
#   inflating: datasets/blogs/880440.female.33.indUnk.Scorpio.xml
#   inflating: datasets/blogs/880688.female.25.Science.Leo.xml
#   inflating: datasets/blogs/882528.male.17.indUnk.Gemini.xml
#   inflating: datasets/blogs/882573.female.23.Communications-Media.Virgo.xml
#   inflating: datasets/blogs/883178.male.36.Fashion.Aries.xml
#   inflating: datasets/blogs/883838.female.48.indUnk.Pisces.xml
#   inflating: datasets/blogs/884715.male.33.BusinessServices.Aquarius.xml
#   inflating: datasets/blogs/886442.female.27.Student.Cancer.xml
#   inflating: datasets/blogs/886530.male.17.indUnk.Virgo.xml
#   inflating: datasets/blogs/887044.female.23.indUnk.Pisces.xml
#   inflating: datasets/blogs/887681.female.26.Religion.Taurus.xml
#   inflating: datasets/blogs/888601.female.24.indUnk.Libra.xml
#   inflating: datasets/blogs/889280.female.17.Student.Aries.xml
#   inflating: datasets/blogs/889780.female.23.indUnk.Sagittarius.xml
#   inflating: datasets/blogs/889952.male.17.indUnk.Gemini.xml
#   inflating: datasets/blogs/890034.female.23.indUnk.Scorpio.xml
#   inflating: datasets/blogs/890200.female.16.indUnk.Sagittarius.xml
#   inflating: datasets/blogs/891211.female.25.indUnk.Scorpio.xml
#   inflating: datasets/blogs/891544.male.27.Student.Libra.xml
#   inflating: datasets/blogs/891567.female.17.indUnk.Libra.xml
#   inflating: datasets/blogs/891800.female.26.Law.Virgo.xml
#   inflating: datasets/blogs/892064.male.26.Student.Sagittarius.xml
#   inflating: datasets/blogs/892173.female.14.indUnk.Libra.xml
#   inflating: datasets/blogs/894444.female.26.indUnk.Taurus.xml
#   inflating: datasets/blogs/894913.male.33.Arts.Sagittarius.xml
#   inflating: datasets/blogs/894945.male.27.Technology.Cancer.xml
#   inflating: datasets/blogs/896120.female.24.Education.Capricorn.xml
#   inflating: datasets/blogs/896714.female.23.Arts.Scorpio.xml
#   inflating: datasets/blogs/898887.male.24.indUnk.Gemini.xml
#   inflating: datasets/blogs/899153.female.27.Religion.Gemini.xml
#   inflating: datasets/blogs/902155.male.17.Non-Profit.Taurus.xml
#   inflating: datasets/blogs/902615.female.25.indUnk.Aquarius.xml
#   inflating: datasets/blogs/904488.male.26.indUnk.Gemini.xml
#   inflating: datasets/blogs/90637.female.36.InvestmentBanking.Gemini.xml
#   inflating: datasets/blogs/906582.female.25.Engineering.Taurus.xml
#   inflating: datasets/blogs/906909.male.24.Education.Libra.xml
#   inflating: datasets/blogs/907388.male.24.Student.Pisces.xml
#   inflating: datasets/blogs/907450.male.25.indUnk.Aries.xml
#   inflating: datasets/blogs/908196.male.43.indUnk.Virgo.xml
#   inflating: datasets/blogs/908687.female.24.indUnk.Pisces.xml
#   inflating: datasets/blogs/911744.male.23.Telecommunications.Capricorn.xml
#   inflating: datasets/blogs/913315.male.25.Communications-Media.Aquarius.xml
#   inflating: datasets/blogs/91374.male.26.indUnk.Taurus.xml
#   inflating: datasets/blogs/917508.male.23.Government.Pisces.xml
#   inflating: datasets/blogs/917929.male.24.Government.Aquarius.xml
#   inflating: datasets/blogs/918175.female.27.indUnk.Aquarius.xml
#   inflating: datasets/blogs/918312.female.27.Communications-Media.Scorpio.xml
#   inflating: datasets/blogs/918695.female.16.Student.Aquarius.xml
#   inflating: datasets/blogs/918871.male.17.Automotive.Leo.xml
#   inflating: datasets/blogs/91888.male.36.Internet.Scorpio.xml
#   inflating: datasets/blogs/919128.male.26.Law.Capricorn.xml
#   inflating: datasets/blogs/920212.female.23.indUnk.Cancer.xml
#   inflating: datasets/blogs/923591.female.25.indUnk.Leo.xml
#   inflating: datasets/blogs/925742.male.16.Student.Gemini.xml
#   inflating: datasets/blogs/926889.male.24.Communications-Media.Aquarius.xml
#   inflating: datasets/blogs/928151.female.24.Student.Libra.xml
#   inflating: datasets/blogs/928859.female.41.Military.Virgo.xml
#   inflating: datasets/blogs/9289.male.23.Marketing.Taurus.xml
#   inflating: datasets/blogs/936098.male.17.Student.Gemini.xml
#   inflating: datasets/blogs/936136.female.25.Telecommunications.Leo.xml
#   inflating: datasets/blogs/937962.female.17.Student.Aquarius.xml
#   inflating: datasets/blogs/939295.male.26.Internet.Gemini.xml
#   inflating: datasets/blogs/939313.male.25.Marketing.Aries.xml
#   inflating: datasets/blogs/941330.male.17.Student.Taurus.xml
#   inflating: datasets/blogs/942103.male.38.Technology.Virgo.xml
#   inflating: datasets/blogs/942828.female.34.indUnk.Cancer.xml
#   inflating: datasets/blogs/944400.female.24.indUnk.Scorpio.xml
#   inflating: datasets/blogs/944569.female.14.Student.Leo.xml
#   inflating: datasets/blogs/944615.female.23.indUnk.Pisces.xml
#   inflating: datasets/blogs/946506.female.25.Education.Aquarius.xml
#   inflating: datasets/blogs/946952.female.25.Education.Leo.xml
#   inflating: datasets/blogs/9470.male.25.Communications-Media.Aries.xml
#   inflating: datasets/blogs/947299.male.24.Law.Gemini.xml
#   inflating: datasets/blogs/949621.female.23.indUnk.Aquarius.xml
#   inflating: datasets/blogs/950122.female.15.Student.Virgo.xml
#   inflating: datasets/blogs/951136.female.16.Student.Libra.xml
#   inflating: datasets/blogs/95161.male.39.indUnk.Capricorn.xml
#   inflating: datasets/blogs/951683.male.23.indUnk.Libra.xml
#   inflating: datasets/blogs/953390.male.16.Student.Pisces.xml
#   inflating: datasets/blogs/955372.female.16.Student.Aries.xml
#   inflating: datasets/blogs/956192.male.33.Internet.Virgo.xml
#   inflating: datasets/blogs/956218.female.33.Biotech.Capricorn.xml
#   inflating: datasets/blogs/956420.male.26.Technology.Cancer.xml
#   inflating: datasets/blogs/956611.female.26.indUnk.Gemini.xml
#   inflating: datasets/blogs/958176.male.17.Non-Profit.Gemini.xml
#   inflating: datasets/blogs/961402.male.17.Student.Aquarius.xml
#   inflating: datasets/blogs/963380.male.24.Student.Cancer.xml
#   inflating: datasets/blogs/96600.female.27.Construction.Virgo.xml
#   inflating: datasets/blogs/966107.male.27.Technology.Sagittarius.xml
#   inflating: datasets/blogs/966973.female.24.indUnk.Sagittarius.xml
#   inflating: datasets/blogs/968707.female.27.Banking.Sagittarius.xml
#   inflating: datasets/blogs/970036.male.23.Student.Libra.xml
#   inflating: datasets/blogs/970774.male.25.Banking.Taurus.xml
#   inflating: datasets/blogs/971317.female.24.indUnk.Aquarius.xml
#   inflating: datasets/blogs/973521.female.34.Religion.Taurus.xml
#   inflating: datasets/blogs/97387.male.23.Arts.Sagittarius.xml
#   inflating: datasets/blogs/977947.female.17.indUnk.Aries.xml
#   inflating: datasets/blogs/978748.male.14.Student.Aquarius.xml
#   inflating: datasets/blogs/979795.male.26.Technology.Taurus.xml
#   inflating: datasets/blogs/980769.male.25.indUnk.Capricorn.xml
#   inflating: datasets/blogs/980975.female.16.indUnk.Pisces.xml
#   inflating: datasets/blogs/983202.male.16.indUnk.Gemini.xml
#   inflating: datasets/blogs/983609.male.24.Non-Profit.Gemini.xml
#   inflating: datasets/blogs/984615.female.27.Technology.Aquarius.xml
#   inflating: datasets/blogs/986006.female.23.indUnk.Taurus.xml
#   inflating: datasets/blogs/987163.female.23.Education.Leo.xml
#   inflating: datasets/blogs/987614.female.16.Student.Gemini.xml
#   inflating: datasets/blogs/988941.female.17.Student.Capricorn.xml
#   inflating: datasets/blogs/989359.female.24.Arts.Sagittarius.xml
#   inflating: datasets/blogs/990045.female.23.indUnk.Gemini.xml
#   inflating: datasets/blogs/991110.female.24.Education.Aquarius.xml
#   inflating: datasets/blogs/992078.male.17.indUnk.Scorpio.xml
#   inflating: datasets/blogs/99290.male.34.Internet.Sagittarius.xml
#   inflating: datasets/blogs/99382.male.25.indUnk.Aquarius.xml
#   inflating: datasets/blogs/993945.female.25.HumanResources.Leo.xml
#   inflating: datasets/blogs/994348.female.27.indUnk.Pisces.xml
#   inflating: datasets/blogs/994616.male.17.Student.Libra.xml
#   inflating: datasets/blogs/996147.female.36.Telecommunications.Leo.xml
#   inflating: datasets/blogs/997488.male.25.indUnk.Cancer.xml
#   inflating: datasets/blogs/998237.female.16.indUnk.Virgo.xml
#   inflating: datasets/blogs/998966.male.27.indUnk.Taurus.xml
#   inflating: datasets/blogs/999503.male.25.Internet.Cancer.xml

# %%
import os
import sys
from pathlib import Path
import shutil
from typing import Generator


def iter_files(folder_path: str) -> Generator[Path, None, None]:
    """
    Recorre recursivamente un directorio y genera rutas de archivos encontrados.

    Args:
        folder_path (str): Ruta del directorio raíz desde el cual se inicia la búsqueda.

    Yields:
        Path: Objeto Path correspondiente a cada archivo encontrado.
    """
    stack: list[Path] = [Path(folder_path)]
    while stack:
        p: Path = stack.pop()
        for entry in os.scandir(p):
            if entry.is_dir(follow_symlinks=False):
                stack.append(Path(entry.path))
            elif entry.is_file(follow_symlinks=False):
                yield Path(entry.path)


def join_files_in_one_stream(
    folder_path: str, 
    output_file_path: str, 
    sep: bytes = b"\n"
) -> None:
    """
    Une todos los archivos de texto en un solo archivo binario.

    Los archivos se concatenan usando buffers grandes para minimizar
    la sobrecarga de Python. Cada archivo se separa con un delimitador.

    Args:
        folder_path (str): Directorio raíz que contiene los archivos a concatenar.
        output_file_path (str): Ruta del archivo de salida que contendrá el stream unido.
        sep (bytes, opcional): Separador a insertar entre archivos. Por defecto b"\\n".

    Raises:
        Exception: Si ocurre algún error al copiar un archivo.
    """
    out_path: Path = Path(output_file_path)
    out_path.parent.mkdir(parents=True, exist_ok=True)

    with open(out_path, "wb") as out_f:
        for fpath in iter_files(folder_path):
            try:
                with open(fpath, "rb") as in_f:
                    shutil.copyfileobj(in_f, out_f, length=1024 * 1024)
                out_f.write(sep)
            except Exception as e:
                print(f"[WARN] No se pudo copiar {fpath}: {e}", file=sys.stderr)


if __name__ == "__main__":
    join_files_in_one_stream("datasets/20news-18828", "large-files/20news.txt")
    join_files_in_one_stream("datasets/blogs", "large-files/blogs.txt")

# %% [markdown]
# (5p) Tokenize by sentence.
# - Normalize, but DO NOT eliminate stop words.
# - Replace numbers with a token named NUM.
# - Add sentence start and end tags "\<s>\</s>".
# - Tokens with unit frequency should be modeled as "\<UNK>".

# %% [markdown]
# Tokenize by sentence

# %%
# !pip install nltk
# Out:
# Requirement already satisfied: nltk in /home/andrew/Documents/procesamiento-lenguaje-natural/prueba-tareas/tarea2/.venv/lib/python3.13/site-packages (3.9.1)
# Requirement already satisfied: click in /home/andrew/Documents/procesamiento-lenguaje-natural/prueba-tareas/tarea2/.venv/lib/python3.13/site-packages (from nltk) (8.2.1)
# Requirement already satisfied: joblib in /home/andrew/Documents/procesamiento-lenguaje-natural/prueba-tareas/tarea2/.venv/lib/python3.13/site-packages (from nltk) (1.5.2)
# Requirement already satisfied: regex>=2021.8.3 in /home/andrew/Documents/procesamiento-lenguaje-natural/prueba-tareas/tarea2/.venv/lib/python3.13/site-packages (from nltk) (2025.9.1)
# Requirement already satisfied: tqdm in /home/andrew/Documents/procesamiento-lenguaje-natural/prueba-tareas/tarea2/.venv/lib/python3.13/site-packages (from nltk) (4.67.1)

# %%
import nltk
nltk.download('punkt_tab')

# %%
from nltk.tokenize import sent_tokenize
import re
from typing import List, Optional


def tokenize_by_sentence(
    input_file: str, 
    is_xml: bool = False, 
    max_chars: Optional[int] = None
) -> List[str]:
    """
    Lee un archivo de texto y lo tokeniza en oraciones.

    Si el archivo contiene formato XML, puede extraer el contenido de las etiquetas <post>...</post>.
    Permite limitar la cantidad de caracteres leídos.

    Args:
        input_file (str): Ruta del archivo de entrada.
        is_xml (bool, opcional): Indica si debe extraer contenido de etiquetas <post>. 
                                 Por defecto False.
        max_chars (int | None, opcional): Número máximo de caracteres a leer del archivo. 
                                          Si es None, se lee todo el archivo.

    Returns:
        List[str]: Lista de oraciones tokenizadas. Si ocurre un error, devuelve lista vacía.
    """
    try:
        print(f"\n[INFO] Abriendo archivo: {input_file}")
        with open(input_file, "r", encoding="latin-1") as infile:
            text: str = infile.read(max_chars) if max_chars else infile.read()
            print(f"[OK] Archivo leído correctamente. Longitud del texto: {len(text)} caracteres")
    except Exception as e:
        print(f"[ERROR] No se pudo leer el archivo {input_file}: {e}")
        return []

    try:
        if is_xml:
            print("[INFO] Extrayendo contenido de <post>...</post>")
            posts: List[str] = re.findall(r"<post>(.*?)</post>", text, flags=re.DOTALL)
            print(f"[OK] Se encontraron {len(posts)} posts")
            if len(posts) == 0:
                print("[WARN] No se encontró nada dentro de <post>...</post>")
            text = "\n".join(posts)
    except Exception as e:
        print(f"[ERROR] Falló la extracción de posts: {e}")
        return []

    try:
        sentences: List[str] = sent_tokenize(text)
        print(f"[OK] Se tokenizaron {len(sentences)} oraciones")
        return sentences
    except Exception as e:
        print(f"[ERROR] Falló la tokenización: {e}")
        return []


if __name__ == "__main__":
    sentences_20news: List[str] = tokenize_by_sentence("large-files/20news.txt")
    sentences_blogs: List[str] = tokenize_by_sentence("large-files/blogs.txt", is_xml=True)

    print("\nEjemplo primeras 5 oraciones 20news:")
    print("20news:", sentences_20news[:5])
    print("\nEjemplo primeras 5 oraciones blogs:")
    print("Blogs:", sentences_blogs[:5])
# Out:
# [INFO] Abriendo archivo: large-files/20news.txt
# [OK] Archivo leído correctamente. Longitud del texto: 33930324 caracteres
# [OK] Se tokenizaron 290240 oraciones
#
# [INFO] Abriendo archivo: large-files/blogs.txt
# [OK] Archivo leído correctamente. Longitud del texto: 799624275 caracteres
# [INFO] Extrayendo contenido de <post>...</post>
# [OK] Se encontraron 681288 posts
# [OK] Se tokenizaron 8813223 oraciones
#
# Ejemplo primeras 5 oraciones 20news:
# 20news: ['From: CGKarras@world.std.com (Christopher G Karras)\nSubject: Need Maintenance tips\n\n\nAfter reading the service manual for my bike (Suzuki GS500E--1990) I have\na couple of questions I hope you can answer:\n\nWhen checking the oil level with the dip stick built into the oil fill\ncap, does one check it with the cap screwed in or not?', 'I am more used to\nthe dip stick for a cage where the stick is extracted fully, wiped clean\nand reinserted fully, then withdrawn and read.', 'The dip stick on my bike\nis part of the oil filler cap and has about 1/2 inch of threads on it.', 'Do\nI remove the cap, wipe the stick clean and reinsert it with/without\nscrewing it down before reading?', 'The service manual calls for the application of Suzuki Bond No.']
#
# Ejemplo primeras 5 oraciones blogs:
# Blogs: ['\n\n\t \n      Today is another "first day" - I put up a few links that I either a) find handy or b) like, because I can either relate or they just plain cracked me up.', 'It is finally Friday.', 'Has anyone else been suffering through this seemingly 14-day week?', 'Sheesh.', 'Someone put me out of my misery and take me out with a tranquilizer dart already.']

# %% [markdown]
# Normalize, but DO NOT eliminate stop words.

# %%
import re

def normalize_text(sentences: List[str]) -> List[str]:
    """
    Normaliza una lista de oraciones:
      - Convierte a minúsculas.
      - Elimina caracteres no alfanuméricos (excepto dígitos y acentos).
      - Reduce espacios múltiples a uno solo.

    Args:
        sentences (List[str]): Lista de oraciones originales.

    Returns:
        List[str]: Lista de oraciones normalizadas.
    """
    normalized_sentences: List[str] = []
    for sentence in sentences:
        sentence = sentence.lower()
        sentence = re.sub(r"[^a-záéíóúüñ\s0-9]", "", sentence)
        sentence = re.sub(r"\s+", " ", sentence).strip()
        normalized_sentences.append(sentence)
    return normalized_sentences


if __name__ == '__main__':
    normalized_20news = normalize_text(sentences_20news)
    normalized_blogs = normalize_text(sentences_blogs)
    
    print("\nEjemplo primeras 5 oraciones normalizadas:")
    print("20news:", normalized_20news[:5])
    print("Blogs:", normalized_blogs[:5])
# Out:
# Ejemplo primeras 5 oraciones normalizadas:
# 20news: ['from cgkarrasworldstdcom christopher g karras subject need maintenance tips after reading the service manual for my bike suzuki gs500e1990 i have a couple of questions i hope you can answer when checking the oil level with the dip stick built into the oil fill cap does one check it with the cap screwed in or not', 'i am more used to the dip stick for a cage where the stick is extracted fully wiped clean and reinserted fully then withdrawn and read', 'the dip stick on my bike is part of the oil filler cap and has about 12 inch of threads on it', 'do i remove the cap wipe the stick clean and reinsert it withwithout screwing it down before reading', 'the service manual calls for the application of suzuki bond no']
# Blogs: ['today is another first day i put up a few links that i either a find handy or b like because i can either relate or they just plain cracked me up', 'it is finally friday', 'has anyone else been suffering through this seemingly 14day week', 'sheesh', 'someone put me out of my misery and take me out with a tranquilizer dart already']

# %% [markdown]
# Replace numbers with a token named NUM.

# %%
import re

def replace_numbers_with_token(normalized_sentences: List[str]) -> List[str]:
    """
    Reemplaza todos los números en una lista de oraciones por el token 'NUM'.

    Args:
        normalized_sentences (List[str]): Lista de oraciones normalizadas.

    Returns:
        List[str]: Lista de oraciones con los números reemplazados por 'NUM'.
    """
    tokenized_sentences: List[str] = []
    for sentence in normalized_sentences:
        sentence_with_token: str = re.sub(r"\d+", "NUM", sentence)
        tokenized_sentences.append(sentence_with_token)
    return tokenized_sentences

if __name__ == '__main__':
    tokenized_num_20news = replace_numbers_with_token(normalized_20news)
    tokenized_num_blogs = replace_numbers_with_token(normalized_blogs)
    
    print("\nEjemplo primeras 5 oraciones con números reemplazados por 'NUM':")
    print("20news:", tokenized_num_20news[:5])
    print("Blogs:", tokenized_num_blogs[:5])
# Out:
# Ejemplo primeras 5 oraciones con números reemplazados por 'NUM':
# 20news: ['from cgkarrasworldstdcom christopher g karras subject need maintenance tips after reading the service manual for my bike suzuki gsNUMeNUM i have a couple of questions i hope you can answer when checking the oil level with the dip stick built into the oil fill cap does one check it with the cap screwed in or not', 'i am more used to the dip stick for a cage where the stick is extracted fully wiped clean and reinserted fully then withdrawn and read', 'the dip stick on my bike is part of the oil filler cap and has about NUM inch of threads on it', 'do i remove the cap wipe the stick clean and reinsert it withwithout screwing it down before reading', 'the service manual calls for the application of suzuki bond no']
# Blogs: ['today is another first day i put up a few links that i either a find handy or b like because i can either relate or they just plain cracked me up', 'it is finally friday', 'has anyone else been suffering through this seemingly NUMday week', 'sheesh', 'someone put me out of my misery and take me out with a tranquilizer dart already']

# %% [markdown]
# - Add sentence start and end tags "\<s>\</s>".

# %%
def add_sentence_tags(sentences: List[str]) -> List[str]:
    """
    Agrega etiquetas de inicio <s> y fin </s> a cada oración de una lista.

    Args:
        sentences (List[str]): Lista de oraciones.

    Returns:
        List[str]: Lista de oraciones con etiquetas de inicio y fin.
    """
    tagged_sentences: List[str] = []
    for sentence in sentences:
        tagged_sentence: str = f"<s> {sentence} </s>"
        tagged_sentences.append(tagged_sentence)
    return tagged_sentences


if __name__ == '__main__':
    tokenized_tags_20news = add_sentence_tags(tokenized_num_20news)
    tokenized_tags_blogs = add_sentence_tags(tokenized_num_blogs)

    print(tokenized_tags_20news[:5])
    print(tokenized_tags_blogs[:5])
# Out:
# ['<s> from cgkarrasworldstdcom christopher g karras subject need maintenance tips after reading the service manual for my bike suzuki gsNUMeNUM i have a couple of questions i hope you can answer when checking the oil level with the dip stick built into the oil fill cap does one check it with the cap screwed in or not </s>', '<s> i am more used to the dip stick for a cage where the stick is extracted fully wiped clean and reinserted fully then withdrawn and read </s>', '<s> the dip stick on my bike is part of the oil filler cap and has about NUM inch of threads on it </s>', '<s> do i remove the cap wipe the stick clean and reinsert it withwithout screwing it down before reading </s>', '<s> the service manual calls for the application of suzuki bond no </s>']
# ['<s> today is another first day i put up a few links that i either a find handy or b like because i can either relate or they just plain cracked me up </s>', '<s> it is finally friday </s>', '<s> has anyone else been suffering through this seemingly NUMday week </s>', '<s> sheesh </s>', '<s> someone put me out of my misery and take me out with a tranquilizer dart already </s>']

# %% [markdown]
# - Tokens with unit frequency should be modeled as "\<UNK>".

# %%
import collections
import re

def replace_single_occurrence_tokens(sentences: List[str]) -> List[str]:
    """
    Reemplaza los tokens que aparecen solo una vez en un corpus por '<UNK>'.

    Args:
        sentences (List[str]): Lista de oraciones a procesar.

    Returns:
        List[str]: Lista de oraciones con tokens de ocurrencia única reemplazados.
    """
    all_tokens: List[str] = []
    for sentence in sentences:
        tokens: List[str] = sentence.split()
        all_tokens.extend(tokens)

    token_counts: collections.Counter = collections.Counter(all_tokens)

    processed_sentences: List[str] = []
    for sentence in sentences:
        current_sentence_tokens: List[str] = sentence.split()
        new_tokens: List[str] = []
        for token in current_sentence_tokens:
            new_tokens.append("<UNK>" if token_counts[token] == 1 else token)
        processed_sentences.append(" ".join(new_tokens))

    return processed_sentences


if __name__ == '__main__':
    processed_20news = replace_single_occurrence_tokens(tokenized_tags_20news)
    processed_blogs = replace_single_occurrence_tokens(tokenized_tags_blogs)

    print("--- Oraciones procesadas de 20news ---")
    print(processed_20news[:10])
    print("\n--- Oraciones procesadas de Blogs ---")
    print(processed_blogs[:10])
# Out:
# --- Oraciones procesadas de 20news ---
# ['<s> from cgkarrasworldstdcom christopher g karras subject need maintenance tips after reading the service manual for my bike suzuki gsNUMeNUM i have a couple of questions i hope you can answer when checking the oil level with the dip stick built into the oil fill cap does one check it with the cap screwed in or not </s>', '<s> i am more used to the dip stick for a cage where the stick is extracted fully wiped clean and reinserted fully then withdrawn and read </s>', '<s> the dip stick on my bike is part of the oil filler cap and has about NUM inch of threads on it </s>', '<s> do i remove the cap wipe the stick clean and reinsert it withwithout screwing it down before reading </s>', '<s> the service manual calls for the application of suzuki bond no </s>', '<s> NUMb on the head cover </s>', '<s> i guess this is some sort of liquid gasket material </s>', '<s> do you know of a generic cheaper substitute </s>', '<s> my headlight is a halogen NUM w bulb </s>', '<s> is there an easy brighter replacement bulb available </s>']
#
# --- Oraciones procesadas de Blogs ---
# ['<s> today is another first day i put up a few links that i either a find handy or b like because i can either relate or they just plain cracked me up </s>', '<s> it is finally friday </s>', '<s> has anyone else been suffering through this seemingly NUMday week </s>', '<s> sheesh </s>', '<s> someone put me out of my misery and take me out with a tranquilizer dart already </s>', '<s> just let me enjoy my weekend first and make sure it has enough drugs to keep me down from next monday to next friday </s>', '<s> but its been a relatively good day </s>', '<s> no downward spirals or wallowing in despair thats the way we like it me myself and i </s>', '<s> me and zoloft what a team </s>', '<s> do you know who they are </s>']

# %% [markdown]
# (10p) Select 80% of the resulting sentences---random without replacement---to build the N-gram model and the remaining 20 for evaluation. Create the following files:
#
# - 20N\_<group\_code>\_training (training sentences)
# - 20N\_<group\_code>\_testing (testing sentences)
# - BAC\_<group\_code>\_training (training sentences)
# - BAC\_<group\_code>\_testing (testing sentences)

# %%
import random
import os
from typing import List


def split_and_save_data(
    sentences: List[str], 
    group_code: str, 
    file_prefix: str
) -> None:
    """
    Divide aleatoriamente una lista de oraciones en 80% entrenamiento y 20% prueba,
    y guarda los conjuntos resultantes en archivos de texto.

    Args:
        sentences (List[str]): Lista de oraciones a dividir.
        group_code (str): Código a incluir en los nombres de archivo (por ejemplo, 'my_group').
        file_prefix (str): Prefijo para los nombres de archivo de salida (por ejemplo, '20N' o 'BAC').

    Returns:
        None: La función no retorna nada. Genera archivos de salida en disco.
    """
    print(f"\n[INFO] Procesando {len(sentences)} oraciones para {file_prefix}")

    random.shuffle(sentences)
    split_index: int = int(len(sentences) * 0.8)

    training_set: List[str] = sentences[:split_index]
    testing_set: List[str] = sentences[split_index:]

    target_directory: str = "tercer-punto"
    if not os.path.exists(target_directory):
        os.makedirs(target_directory)

    training_filename: str = os.path.join(
        target_directory, f"{file_prefix}_{group_code}_training.txt"
    )
    testing_filename: str = os.path.join(
        target_directory, f"{file_prefix}_{group_code}_testing.txt"
    )

    try:
        with open(training_filename, "w", encoding="utf-8") as f:
            for sentence in training_set:
                f.write(f"{sentence}\n")
        print(
            f"[OK] Guardado el conjunto de entrenamiento en '{training_filename}' "
            f"({len(training_set)} oraciones)"
        )

        with open(testing_filename, "w", encoding="utf-8") as f:
            for sentence in testing_set:
                f.write(f"{sentence}\n")
        print(
            f"[OK] Guardado el conjunto de prueba en '{testing_filename}' "
            f"({len(testing_set)} oraciones)"
        )
    except Exception as e:
        print(f"[ERROR] No se pudieron guardar los archivos: {e}")


if __name__ == "__main__":
    group_code: str = "my_group"

    split_and_save_data(processed_20news, group_code, "20N")
    split_and_save_data(processed_blogs, group_code, "BAC")
# Out:
# [INFO] Procesando 290240 oraciones para 20N
# [OK] Guardado el conjunto de entrenamiento en 'tercer-punto/20N_my_group_training.txt' (232192 oraciones)
# [OK] Guardado el conjunto de prueba en 'tercer-punto/20N_my_group_testing.txt' (58048 oraciones)
#
# [INFO] Procesando 8813223 oraciones para BAC
# [OK] Guardado el conjunto de entrenamiento en 'tercer-punto/BAC_my_group_training.txt' (7050578 oraciones)
# [OK] Guardado el conjunto de prueba en 'tercer-punto/BAC_my_group_testing.txt' (1762645 oraciones)

# %% [markdown]
# (50p) Build the following N-gram models using Laplace smoothing and generate an output file for each one (you choose the output structure, but be sure to provide an appropriate Python reading method/function):
#
# - 20N\_<group\_code>\_unigrams
# - 20N\_<group\_code>\_bigrams
# - 20N\_<group\_code>\_trigrams
# - BAC\_<group\_code>\_unigrams
# - BAC\_<group\_code>\_bigrams
# - BAC\_<group\_code>\_trigrams

# %%
import json
import collections
import os
import re

def build_ngram_models(
    corpus_file: str, 
    group_code: str, 
    file_prefix: str
) -> None:
    """
    Construye modelos de unigramas, bigramas y trigramas con suavizado de Laplace 
    a partir de un corpus de texto y los guarda como archivos JSON.

    Args:
        corpus_file (str): Ruta del archivo de texto (datos de entrenamiento).
        group_code (str): Código a incluir en los nombres de archivo de salida.
        file_prefix (str): Prefijo para los nombres de archivo (ejemplo: '20N' o 'BAC').

    Returns:
        None: La función no devuelve nada. Genera archivos JSON con los modelos.
    """
    # Crea el directorio para los modelos si no existe
    models_dir = os.path.join("cuarto-punto", "models")
    if not os.path.exists(models_dir):
        os.makedirs(models_dir)

    # Lee el corpus de texto
    try:
        with open(corpus_file, 'r', encoding='utf-8') as f:
            sentences = [line.strip() for line in f if line.strip()]
        if not sentences:
            print(f"[WARN] No se encontraron oraciones en el archivo: {corpus_file}")
            return
        print(f"[OK] Leído el corpus de entrenamiento de '{corpus_file}' con {len(sentences)} oraciones.")
    except Exception as e:
        print(f"[ERROR] No se pudo leer el archivo '{corpus_file}': {e}")
        return

    # Procesa los tokens para todos los modelos
    all_tokens = ' '.join(sentences).split()
    vocab_size = len(set(all_tokens))
    
    # 1. Construye y guarda el modelo de Unigramas
    unigram_counts = collections.Counter(all_tokens)
    unigram_model = {}
    total_tokens = len(all_tokens)
    for token, count in unigram_counts.items():
        unigram_model[token] = (count + 1) / (total_tokens + vocab_size)
    
    unigram_path = os.path.join(models_dir, f"{file_prefix}_{group_code}_unigrams.json")
    with open(unigram_path, 'w', encoding='utf-8') as f:
        json.dump(unigram_model, f, ensure_ascii=False, indent=4)
    print(f"[OK] Modelo de unigramas guardado en '{unigram_path}'")
    
    # 2. Construye y guarda el modelo de Bigramas
    bigram_counts = collections.Counter()
    unigram_context_counts = collections.Counter()
    for sentence in sentences:
        tokens = sentence.split()
        for i in range(len(tokens) - 1):
            bigram_counts[(tokens[i], tokens[i+1])] += 1
            unigram_context_counts[tokens[i]] += 1
    
    bigram_model = {}
    for (token1, token2), count in bigram_counts.items():
        context_count = unigram_context_counts[token1]
        probability = (count + 1) / (context_count + vocab_size)
        bigram_model[f"{token1} {token2}"] = probability
        
    bigram_path = os.path.join(models_dir, f"{file_prefix}_{group_code}_bigrams.json")
    with open(bigram_path, 'w', encoding='utf-8') as f:
        json.dump(bigram_model, f, ensure_ascii=False, indent=4)
    print(f"[OK] Modelo de bigramas guardado en '{bigram_path}'")
    
    # 3. Construye y guarda el modelo de Trigramas
    trigram_counts = collections.Counter()
    bigram_context_counts = collections.Counter()
    for sentence in sentences:
        tokens = sentence.split()
        for i in range(len(tokens) - 2):
            trigram_counts[(tokens[i], tokens[i+1], tokens[i+2])] += 1
            bigram_context_counts[(tokens[i], tokens[i+1])] += 1
            
    trigram_model = {}
    for (token1, token2, token3), count in trigram_counts.items():
        context_count = bigram_context_counts.get((token1, token2), 0)
        probability = (count + 1) / (context_count + vocab_size)
        trigram_model[f"{token1} {token2} {token3}"] = probability

    trigram_path = os.path.join(models_dir, f"{file_prefix}_{group_code}_trigrams.json")
    with open(trigram_path, 'w', encoding='utf-8') as f:
        json.dump(trigram_model, f, ensure_ascii=False, indent=4)
    print(f"[OK] Modelo de trigramas guardado en '{trigram_path}'")


if __name__ == '__main__':
    group_code = "my_group"
    
    training_file_20N = os.path.join("tercer-punto", f"20N_{group_code}_training.txt")
    training_file_BAC = os.path.join("tercer-punto", f"BAC_{group_code}_training.txt")
    
    # Construye y guarda los modelos
    build_ngram_models(training_file_20N, group_code, "20N")
    build_ngram_models(training_file_BAC, group_code, "BAC")
# Out:
# [OK] Leído el corpus de entrenamiento de 'tercer-punto/20N_my_group_training.txt' con 232192 oraciones.
# [OK] Modelo de unigramas guardado en 'cuarto-punto/models/20N_my_group_unigrams.json'
# [OK] Modelo de bigramas guardado en 'cuarto-punto/models/20N_my_group_bigrams.json'
# [OK] Modelo de trigramas guardado en 'cuarto-punto/models/20N_my_group_trigrams.json'
# [OK] Leído el corpus de entrenamiento de 'tercer-punto/BAC_my_group_training.txt' con 7050578 oraciones.
# [OK] Modelo de unigramas guardado en 'cuarto-punto/models/BAC_my_group_unigrams.json'
# [OK] Modelo de bigramas guardado en 'cuarto-punto/models/BAC_my_group_bigrams.json'
# [OK] Modelo de trigramas guardado en 'cuarto-punto/models/BAC_my_group_trigrams.json'
